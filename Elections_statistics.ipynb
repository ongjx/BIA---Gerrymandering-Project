# %%
import pandas as pd
import numpy as np
df = pd.read_csv('parliamentary-general-election-results-by-candidate.csv')

# %%
df.sample(12)
# Out:
#       year       constituency constituency_type              candidates  \
# 650   1972       Potong Pasir                na   Baptist Ivan Cuthbert
# 672   1972           Tampines                na            Tan Sim Hock
# 183   1959        Mountbatten                na             Tay Kum Sun
# 52    1955          Serangoon                na          Lim Choon Mong
# 1059  1984         West Coast                na              M Ramasamy
# 738   1976          Henderson                na           Hoe Boon Teck
# 351   1963         Jalan Kayu                na             Ong Yu Thoh
# 769   1976           Leng Kee                na            Ng Lep Chong
# 270   1959    Upper Serangoon                na          Lim Choon Mong
# 217   1959  Serangoon Gardens                na  Liao Ping alias Thomas
# 768   1976          Kuo Chuan                na           P. Selvadurai
# 372   1963      Kampong Kapor                na       Nalliah Karuppiah
#
#             party vote_count vote_percentage
# 650           PAP       7772          0.6622
# 672            PF       5025           0.357
# 183           PAP       2143          0.2384
# 52             PP       2172          0.4583
# 1059          JPS       6331          0.2428
# 738            WP       4338          0.2523
# 351   Independent        516          0.0593
# 769            UF       4043          0.2324
# 270           SPA       4372          0.4381
# 217          PKMS        853          0.1086
# 768           PAP      11931          0.7442
# 372           UPP       1143          0.1053

# %%
df = df.set_index('constituency')
df.sample(20)
# Out:
#                year constituency_type  \
# constituency
# Joo Chiat      2001               SMC
# Bukit Gombak   1997               SMC
# Changi         1959                na
# Potong Pasir   1968                na
# River Valley   1972                na
# Jalan Besar    2006               GRC
# Hong Lim       1963                na
# Pasir Panjang  1963                na
# Rochore        1984                na
# Havelock       1968                na
# Farrer Park    1955                na
# Khe Bong       1984                na
# Changi         1968                na
# Bukit Panjang  1963                na
# Geylang Serai  1963                na
# Rochore        1968                na
# Jalan Besar    1997               GRC
# Seletar        1955                na
# Tanglin        1984                na
# Punggol        1976                na
#
#                                                       candidates        party  \
# constituency
# Joo Chiat                                           Chan Soo Sen          PAP
# Bukit Gombak                                       Ang Mong Seng          PAP
# Changi                                            Lim Cher Kheng  Independent
# Potong Pasir                                  Sellappa Ramaswamy          PAP
# River Valley                                       Tan Eng Liang          PAP
# Jalan Besar    Cheo Chai Chen | Fong Chin Leong | Muhamad Ali...          SDA
# Hong Lim                                            Sam Tai Guan           SA
# Pasir Panjang                                     Tay Cheng Kang           BS
# Rochore                                            Toh Chin Chye          PAP
# Havelock                                            Lim Soo Peng          PAP
# Farrer Park                                       Eric S. B. Wee           PP
# Khe Bong                                           Sim Say Chuan           BS
# Changi                                              Sim Boon Woo          PAP
# Bukit Panjang                                     Lee Khoon Choy          PAP
# Geylang Serai                                      Darus Shariff  Independent
# Rochore                                            Toh Chin Chye          PAP
# Jalan Besar    Choo Wee Khiang | Lee Boon Yang | Peh Chin Hua...          PAP
# Seletar                                           Tan Leong Teck           DP
# Tanglin                                               E W Barker          PAP
# Punggol                                             Tan Yong Sin           WP
#
#               vote_count vote_percentage
# constituency
# Joo Chiat          15426          0.8355
# Bukit Gombak       15229          0.6514
# Changi              2225          0.2245
# Potong Pasir          na              na
# River Valley          na              na
# Jalan Besar        26151          0.3074
# Hong Lim             191          0.0168
# Pasir Panjang       1887          0.2969
# Rochore               na              na
# Havelock              na              na
# Farrer Park         1784          0.2659
# Khe Bong            5525          0.3747
# Changi                na              na
# Bukit Panjang       4940          0.4041
# Geylang Serai       1059          0.0756
# Rochore               na              na
# Jalan Besar        44840          0.6755
# Seletar             1252           0.225
# Tanglin               na              na
# Punggol             5887          0.3059

# %% [markdown]
# # Data Cleaning

# %%
print(df.dtypes)
# Out:
# year                  int64
# constituency_type    object
# candidates           object
# party                object
# vote_count           object
# vote_percentage      object
# dtype: object

# %% [markdown]
# ## Replace "na" values for vote_count and vote_percentage

# %%
df['vote_count'] = df['vote_count'].replace("na", 0)
df['vote_percentage'] = df['vote_percentage'].replace("na", 0)
df['year'] = df['year'].apply(np.int)
df['vote_count'] = df['vote_count'].apply(np.int)
df['vote_percentage'] = df['vote_percentage'].apply(np.float)

df.sample(10)
print(df.dtypes)
# Out:
# year                   int64
# constituency_type     object
# candidates            object
# party                 object
# vote_count             int64
# vote_percentage      float64
# dtype: object

# %%
df = df.reset_index()
df.tail()
# Out:
#        constituency  year constituency_type  \
# 1470  Tanjong Pagar  2015               GRC
# 1471     West Coast  2015               GRC
# 1472     West Coast  2015               GRC
# 1473          Yuhua  2015               SMC
# 1474          Yuhua  2015               SMC
#
#                                              candidates party  vote_count  \
# 1470  Chan Chun Sing | Chia Shi-Lu | Indranee Thurai...   PAP       90635
# 1471  Foo Mee Har | Lim Hng Kiang | Siswaran | Patri...   PAP       71214
# 1472  Kenneth Andrew Jeyaretnam | Noraini Bte Yunus ...    RP       19426
# 1473                                  Grace Fu Hai Yien   PAP       15324
# 1474                                        Go Hui Leng   SDP        5512
#
#       vote_percentage
# 1470           0.7771
# 1471           0.7857
# 1472           0.2143
# 1473           0.7355
# 1474           0.2645

# %%
df.dtypes
# Out:
# constituency          object
# year                   int64
# constituency_type     object
# candidates            object
# party                 object
# vote_count             int64
# vote_percentage      float64
# dtype: object

# %%
df2 = df.set_index("year")
df2 = df2.loc[[2011, 2015]]
df2 = df2.groupby(['year','constituency']).max()
df2
# Out:
#                          constituency_type  \
# year constituency
# 2011 Aljunied                          GRC
#      Ang Mo Kio                        GRC
#      Bishan-Toa Payoh                  GRC
#      Bukit Panjang                     SMC
#      Chua Chu Kang                     GRC
#      East Coast                        GRC
#      Holland-Bukit Timah               GRC
#      Hong Kah North                    SMC
#      Hougang                           SMC
#      Joo Chiat                         SMC
#      Jurong                            GRC
#      Marine Parade                     GRC
#      Moulmein-Kallang                  GRC
#      Mountbatten                       SMC
#      Nee Soon                          GRC
#      Pasir Ris-Punggol                 GRC
#      Pioneer                           SMC
#      Potong Pasir                      SMC
#      Punggol East                      SMC
#      Radin Mas                         SMC
#      Sembawang                         GRC
#      Sengkang West                     SMC
#      Tampines                          GRC
#      Tanjong Pagar                     GRC
#      West Coast                        GRC
#      Whampoa                           SMC
#      Yuhua                             SMC
# 2015 Aljunied                          GRC
#      Ang Mo Kio                        GRC
#      Bishan-Toa Payoh                  GRC
#      Bukit Batok                       SMC
#      Bukit Panjang                     SMC
#      Chua Chu Kang                     GRC
#      East Coast                        GRC
#      Fengshan                          SMC
#      Holland-Bukit Timah               GRC
#      Hong Kah North                    SMC
#      Hougang                           SMC
#      Jalan Besar                       GRC
#      Jurong                            GRC
#      MacPherson                        SMC
#      Marine Parade                     GRC
#      Marsiling-Yew Tee                 GRC
#      Mountbatten                       SMC
#      Nee Soon                          GRC
#      Pasir Ris-Punggol                 GRC
#      Pioneer                           SMC
#      Potong Pasir                      SMC
#      Punggol East                      SMC
#      Radin Mas                         SMC
#      Sembawang                         GRC
#      Sengkang West                     SMC
#      Tampines                          GRC
#      Tanjong Pagar                     GRC
#      West Coast                        GRC
#      Yuhua                             SMC
#
#                                                                  candidates  \
# year constituency
# 2011 Aljunied             Lim Hwee Hua | Ong Ye Kung | Cynthia Phua | Ge...
#      Ang Mo Kio           Lim Tung Hee Arthero | Lim Zirui | Mohamed Man...
#      Bishan-Toa Payoh     Hri Kumar Nair | Ng Eng Hen | Josephine Teo | ...
#      Bukit Panjang                                               Teo Ho Pin
#      Chua Chu Kang        Jeisialn Sivalingam | Nor Lella Mardiiiah Bte ...
#      East Coast           Lee Yi Shyan | Lim Siang Keat Raymond | Lim Sw...
#      Holland-Bukit Timah  De Souza Christopher Jamed | Liang Eng Hwa | S...
#      Hong Kah North                                            Sin Kek Tong
#      Hougang                                                 Yaw Shin Leong
#      Joo Chiat                                                Yee Jenn Jong
#      Jurong               Ang Wei Neng | Halimah Binte Yacob | Desmond L...
#      Marine Parade        Fatimah Binte Abdul Lateef | Goh Chok Tong | S...
#      Moulmein-Kallang     Lui Tuck Yew | Phua Lay Peng Denise | Edwin To...
#      Mountbatten                                             Lim Biow Chuan
#      Nee Soon             K Shanmugam | Lee Bee Wah | Lim Wee Kiak | Muh...
#      Pasir Ris-Punggol    Harminder Pal Singh | Lee Song Juan | Jeffrey ...
#      Pioneer                                                     Chia Steve
#      Potong Pasir                                             Sitoh Yih Pin
#      Punggol East                                            Michael Palmer
#      Radin Mas                                                 Yip Yew Weng
#      Sembawang            James Gomez | Luo Jie Jarrod | Mohd Isa | Sada...
#      Sengkang West                                              Lam Pin Min
#      Tampines             Fong Chin Leong | Goh Keow Wah| Goh Meng Seng ...
#      Tanjong Pagar        Chan Chun Sing | Chia Shi-Lu | Indranee Thurai...
#      West Coast           Ho Soak Harn | Kenneth Andrew Jeyaretnam | Kum...
#      Whampoa                                                        Ken Sun
#      Yuhua                                                     Teo Soh Lung
# 2015 Aljunied             Chen Show Mao | Sylvia Lim | Low Thia Khiang |...
#      Ang Mo Kio           Goh Keow Wah | Jesse Loo Hoe Bock | Roy Ngerng...
#      Bishan-Toa Payoh     Law Kim Hwee | Long YaoGuang, Don Bryan | Moha...
#      Bukit Batok                                           Samir Salim Neji
#      Bukit Panjang                                               Teo Ho Pin
#      Chua Chu Kang        Goh Meng Seng | Lee Tze Shih | Low Wai Choo | ...
#      East Coast           Lee Yi Shyan | Lim Swee Say | Mohd Maliki Bin ...
#      Fengshan                                           Dennis Tan Lip Fong
#      Holland-Bukit Timah  Christopher De Souza | Liang Eng Hwa | Sim Ann...
#      Hong Kah North                                           Ravi Philemon
#      Hougang                                                   Png Eng Huat
#      Jalan Besar          Heng Chee How | Lily Neo | Denise Phua Lay Pen...
#      Jurong               Foo Ming Jin David | Sukdeu Singh | Tan Peng A...
#      MacPherson                                                Tin Pei Ling
#      Marine Parade        Firuz Khan | He Tingru | Ng Foo Eng | Terence ...
#      Marsiling-Yew Tee    Halimah Yacob | Ong Teng Koon | Lawrence Wong ...
#      Mountbatten                                             Lim Biow Chuan
#      Nee Soon             K Shanmugam | Kwek Hian Chuan | Lee Bee Wah | ...
#      Pasir Ris-Punggol    Janil Puthucheary | Ng Chee Meng | Sun XueLing...
#      Pioneer                                            Ong Beng Soon Elvin
#      Potong Pasir                                             Sitoh Yih Pin
#      Punggol East                                               Lee Li Lian
#      Radin Mas                                               Tan Chin Siong
#      Sembawang            Amrin Amin | Khaw Boon Wan | Lim Wee Kiak | On...
#      Sengkang West                                              Lam Pin Min
#      Tampines             Choong Hon Heng | Fong Chin Leong | Lim Tean |...
#      Tanjong Pagar        Chan Chun Sing | Chia Shi-Lu | Indranee Thurai...
#      West Coast           Kenneth Andrew Jeyaretnam | Noraini Bte Yunus ...
#      Yuhua                                                Grace Fu Hai Yien
#
#                          party  vote_count  vote_percentage
# year constituency
# 2011 Aljunied               WP       72289           0.5472
#      Ang Mo Kio             RP      112677           0.6933
#      Bishan-Toa Payoh      SPP       62385           0.5693
#      Bukit Panjang         SDP       20375           0.6627
#      Chua Chu Kang         PAP       89710           0.6120
#      East Coast             WP       59992           0.5483
#      Holland-Bukit Timah   SDP       48773           0.6008
#      Hong Kah North        SPP       18156           0.7061
#      Hougang                WP       14850           0.6480
#      Joo Chiat              WP        9666           0.5102
#      Jurong                PAP       76595           0.6696
#      Marine Parade         PAP       78286           0.5664
#      Moulmein-Kallang       WP       44886           0.5855
#      Mountbatten           PAP       11985           0.5862
#      Nee Soon               WP       80740           0.5840
#      Pasir Ris-Punggol     SDA      100493           0.6479
#      Pioneer               PAP       14593           0.6073
#      Potong Pasir          SPP        7992           0.5036
#      Punggol East           WP       16994           0.5454
#      Radin Mas             PAP       18609           0.6710
#      Sembawang             SDP       84252           0.6390
#      Sengkang West          WP       14689           0.5811
#      Tampines              PAP       72728           0.5722
#      Tanjong Pagar         PAP           0           0.0000
#      West Coast             RP       72563           0.6657
#      Whampoa               PAP       13028           0.6610
#      Yuhua                 SDP       14093           0.6686
# 2015 Aljunied               WP       70050           0.5096
#      Ang Mo Kio             RP      135316           0.7864
#      Bishan-Toa Payoh      SPP       86701           0.7359
#      Bukit Batok           SDP       18234           0.7302
#      Bukit Panjang         SDP       21954           0.6838
#      Chua Chu Kang         PPP       84850           0.7691
#      East Coast             WP       55093           0.6073
#      Fengshan               WP       12417           0.5750
#      Holland-Bukit Timah   SDP       62786           0.6660
#      Hong Kah North        SPP       19628           0.7476
#      Hougang                WP       13027           0.5766
#      Jalan Besar            WP       63644           0.6775
#      Jurong                SGF       95228           0.7929
#      MacPherson             WP       17251           0.6560
#      Marine Parade          WP       85138           0.6407
#      Marsiling-Yew Tee     SDP       68546           0.6873
#      Mountbatten           SPP       15331           0.7186
#      Nee Soon               WP       82287           0.6683
#      Pasir Ris-Punggol     SDA      125166           0.7289
#      Pioneer               PAP       18017           0.7635
#      Potong Pasir          SPP       10602           0.6639
#      Punggol East           WP       16977           0.5177
#      Radin Mas              RP       20246           0.7725
#      Sembawang             PAP       96718           0.7228
#      Sengkang West          WP       17586           0.6213
#      Tampines              PAP       95305           0.7207
#      Tanjong Pagar         SGF       90635           0.7771
#      West Coast             RP       71214           0.7857
#      Yuhua                 SDP       15324           0.7355

# %%
df3 = df2.reset_index()
# common_constituency = df3.constituency.value_counts()==2
# df3.loc[df3.groupby('constituency').count().reset_index()['year'] == 2]
# df3[df3['year'] == 2011]
# df3.loc[df3[df3['year'] == 2015]['constituency'].isin(common_constituency).index].count()
df_2011 = df3.loc[df3['year'] == 2011]
df_2015 = df3.loc[df3['year'] == 2015]

common_constituency = list(set(df_2011['constituency']).intersection(set(df_2015['constituency'])))
df_2011 = df_2011[df_2011['constituency'].isin(common_constituency)]
df_2015 = df_2015[df_2015['constituency'].isin(common_constituency)]
df_2011.drop(["year","candidates"],axis=1,inplace=True)
df_2015.drop(['year',"candidates"],axis=1,inplace=True)
df_2015 = df_2015.set_index(['constituency', 'constituency_type', 'party'])
df_2011 = df_2011.set_index(['constituency', 'constituency_type', 'party'])

# %%
x = df_2015.sub(df_2011)

# %%
import pprint
data = {'Bishan': ['Bishan-Toa Payoh'], 'Bukit Merah': ['Jalan Besar', 'Radin Mas', 'Tanjong Pagar', 'West Coast'], 'Geylang': ['Jalan Besar', 'MacPherson', 'Marine Parade', 'Mountbatten', 'Potong Pasir'], 'Kallang': ['Jalan Besar', 'Mountbatten', 'Tanjong Pagar'], 'Marine Parade': ['Marine Parade', 'Mountbatten'], 'Queenstown': ['Holland-Bukit Timah', 'Tanjong Pagar', 'West Coast'], 'Toa Payoh': ['Bishan-Toa Payoh', 'Marine Parade', 'Potong Pasir'], 'Bedok': ['Aljunied', 'East Coast', 'Fengshan', 'Marine Parade'], 'Changi': ['East Coast'], 'Pasir Ris': ['Pasir Ris-Punggol'], 'North-Eastern Islands': ['East Coast'], 'Tampines': ['Aljunied', 'Pasir Ris-Punggol', 'East Coast', 'Tampines'], 'Central Water Catchment': ['Holland-Bukit Timah'], 'Woodlands': ['Marsiling-Yew Tee', 'Sembawang'], 'Ang Mo Kio': ['Ang Mo Kio', 'Nee Soon'], 'Bukit Batok': ['Bukit Batok', 'Chua Chu Kang', 'Hong Kah North', 'Jurong'], 'Bukit Panjang': ['Bukit Panjang', 'Holland-Bukit Timah'], 'Clementi': ['Holland-Bukit Timah', 'Jurong', 'West Coast'], 'Bukit Timah': ['Holland-Bukit Timah', 'Jurong', 'Tanjong Pagar'], 'Central Area': ['Jalan Besar', 'Mountbatten', 'Tanjong Pagar'], 'Jurong East': ['Jurong', 'West Coast', 'Yuhua'], 'Tuas': ['West Coast'], 'Western Water Catchment': ['Chua Chu Kang'], 'Sungei Kadut': ['Marsiling-Yew Tee'], 'Choa Chu Kang': ['Chua Chu Kang', 'Marsiling-Yew Tee'], 'Tengah': ['Hong Kah North'], 'Novena': ['Bishan-Toa Payoh', 'Holland-Bukit Timah', 'Jalan Besar', 'Tanjong Pagar'], 'Serangoon': ['Aljunied', 'Ang Mo Kio', 'Marine Parade'], 'Hougang': ['Aljunied', 'Ang Mo Kio', 'Hougang', 'Marine Parade'], 'Mandai': ['Marsiling-Yew Tee ', 'Nee Soon'], 'Yishun': ['Ang Mo Kio', 'Nee Soon', 'Sembawang'], 'Sembawang': ['Sembawang'], 'Seletar': ['Ang Mo Kio'], 'Punggol': ['Pasir Ris-Punggol']}

scraped_data = {}
for key in data:
    list_of_const = data[key]
    
    for item in list_of_const:
        if item not in scraped_data:
            scraped_data[item] = [key]
        else:
            scraped_data[item] += [key]
    
pprint.pprint(scraped_data)
# Out:
# {'Aljunied': ['Bedok', 'Tampines', 'Serangoon', 'Hougang'],
#  'Ang Mo Kio': ['Ang Mo Kio', 'Serangoon', 'Hougang', 'Yishun', 'Seletar'],
#  'Bishan-Toa Payoh': ['Bishan', 'Toa Payoh', 'Novena'],
#  'Bukit Batok': ['Bukit Batok'],
#  'Bukit Panjang': ['Bukit Panjang'],
#  'Chua Chu Kang': ['Bukit Batok', 'Western Water Catchment', 'Choa Chu Kang'],
#  'East Coast': ['Bedok', 'Changi', 'North-Eastern Islands', 'Tampines'],
#  'Fengshan': ['Bedok'],
#  'Holland-Bukit Timah': ['Queenstown',
#                          'Central Water Catchment',
#                          'Bukit Panjang',
#                          'Clementi',
#                          'Bukit Timah',
#                          'Novena'],
#  'Hong Kah North': ['Bukit Batok', 'Tengah'],
#  'Hougang': ['Hougang'],
#  'Jalan Besar': ['Bukit Merah', 'Geylang', 'Kallang', 'Central Area', 'Novena'],
#  'Jurong': ['Bukit Batok', 'Clementi', 'Bukit Timah', 'Jurong East'],
#  'MacPherson': ['Geylang'],
#  'Marine Parade': ['Geylang',
#                    'Marine Parade',
#                    'Toa Payoh',
#                    'Bedok',
#                    'Serangoon',
#                    'Hougang'],
#  'Marsiling-Yew Tee': ['Woodlands', 'Sungei Kadut', 'Choa Chu Kang'],
#  'Marsiling-Yew Tee ': ['Mandai'],
#  'Mountbatten': ['Geylang', 'Kallang', 'Marine Parade', 'Central Area'],
#  'Nee Soon': ['Ang Mo Kio', 'Mandai', 'Yishun'],
#  'Pasir Ris-Punggol': ['Pasir Ris', 'Tampines', 'Punggol'],
#  'Potong Pasir': ['Geylang', 'Toa Payoh'],
#  'Radin Mas': ['Bukit Merah'],
#  'Sembawang': ['Woodlands', 'Yishun', 'Sembawang'],
#  'Tampines': ['Tampines'],
#  'Tanjong Pagar': ['Bukit Merah',
#                    'Kallang',
#                    'Queenstown',
#                    'Bukit Timah',
#                    'Central Area',
#                    'Novena'],
#  'West Coast': ['Bukit Merah', 'Queenstown', 'Clementi', 'Jurong East', 'Tuas'],
#  'Yuhua': ['Jurong East']}
