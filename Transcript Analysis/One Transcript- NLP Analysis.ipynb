# %%
# Importing Packages

import nltk #Tokenizing
import re #Preprocessing
import matplotlib.pyplot as plt
import bs4 as bs
import urllib.request #Scraping
import heapq #getting the top k largest sentences

# Importing classes within the packages

from nltk.corpus import PlaintextCorpusReader
from nltk.corpus import stopwords #Don't consider stopwords in histogram
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import *
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk import FreqDist
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# We specify the directory where the transcripts are
file_directory = 'transcripts'
 
# We include those filenames ending with '.txt'.
filename_pattern = '.+\.txt'
my_corpus = PlaintextCorpusReader(file_directory, filename_pattern)

# %%
print(my_corpus.fileids())

# This is for future use to apply the code to all the text files in the folder
# Out:
# ['01_02_19.txt', '01_06_18.txt', '01_09_11.txt', '01_10_15.txt', '02_02_11.txt', '03_08_11.txt', '08_07_11.txt', '08_08_11.txt', '11_10_18.txt', '12_09_18.txt', '13_11_15.txt', '14_08_11.txt', '14_11_18.txt', '15_11_18.txt', '16_03_18.txt', '16_05_18.txt', '16_08_11.txt', '16_11_18.txt', '17_02_15.txt', '18_05_11.txt', '19_08_09.txt', '19_08_18.txt', '21_05_11.txt', '21_10_11.txt', '23_08_15.txt', '24_04_18.txt', '24_09_15.txt', '25_01_19.txt', '26_04_18.txt', '26_10_15.txt', '27_04_18.txt', '27_09_15.txt', '28_04_18.txt', '28_09_15.txt', '29_03_15.txt', '29_08_11.txt', '29_09_15.txt', '31_08_11.txt', '31_10_11.txt', '31_10_15.txt']

# %%
# Extract sentences

sentences = my_corpus.sents('19_08_09.txt')
sent_list=[] # A list of all sentences in the transcript

for key1 in sentences:
    s=""
    for key2 in key1:
        s=s+key2+" "
    sent_list.append(s)

# %%
# Extract words from text file

transcript01 = my_corpus.words('19_08_09.txt')
print(transcript01)

# Here, we need to rmeove the punctuation marks from the list.
# So, we adopt a different approach using strings
# Out:
# ['"', 'Sir', ',', 'I', 'had', 'not', 'intended', 'to', ...]

# %%
# Reading the text file

data=''
with open('transcripts/19_08_09.txt','r') as file:
    for line in file:
        s = str(line).strip()
        data = data + s + ' '
        
data = data.lower() # Contains all the data in the transcript as a string

# %%
data_split = data.split(" ")
print(len(data_split))
# Out:
# 912

# %%
# Removing punctuations and only considering words

pattern = r"\w+"
reg_split = re.findall(pattern,data) # A list of all words in the transcript

print(len(reg_split))
# Out:
# 887

# %%
# Tokenizing all the data

tokenizer = RegexpTokenizer(r'\w+')

data_tokens = tokenizer.tokenize(data)

print(len(data_tokens))
# Out:
# 887

# %%
# Now we remove stopwords from the data

stop_words = stopwords.words('english')

clean_data = []
print("Before removing stopwords: " , len(data_tokens))

for w in data_tokens:
    if w not in stop_words:
        clean_data.append(w)        

print("After removing stopwords: " , len(clean_data))
# Out:
# Before removing stopwords:  887
# After removing stopwords:  410

# %%
# We stem the data using Porter Stemmer

stemmed_data=[]
stemmer = PorterStemmer()

for w in clean_data:
    stemmed_data.append(stemmer.stem(w))
    
print(len(stemmed_data))
# Out:
# 410

# %%
# Attach Parts of Speech to each word belonging to the clean data

pos_data = pos_tag(clean_data)
print(len(pos_data))
# Out:
# 410

# %%
# We simplify the Parts of Speech tags
# We want to convert NNS to n and VBD to v

data_output=[]

for w in pos_data:
    data_output.append((w[0], w[1][0].lower()))

print(len(data_output))
# Out:
# 410

# %%
# We use a Word Lemmatizer
lemmatizer = WordNetLemmatizer()
lemmatized_data=[]

for w in clean_data: 
    lemmatized_data.append(lemmatizer.lemmatize(w))

print(len(lemmatized_data))
# Out:
# 410

# %%
# We combine the POS Tags and Lemmatized data

lemma_output_data = []
lemma_words=[]

for w in data_output:
    word = w[0]
    pos_word = w[1]
    lemma = word
    if pos_word in ['a', 's', 'r', 'n', 'v']:
        lemma = lemmatizer.lemmatize(word, pos=pos_word)
        lemma_words.append(lemma)
    
    #return (word, pos_tag, lemma)
    lemma_output_data.append((word,pos_word,lemma))
    
print(len(lemma_output_data))
# Out:
# 410

# %%
# Getting frequencies

data_freq=[]

for lemma_tag in lemma_output_data:
    data_freq.append(lemma_tag[2])
    
print(data_freq)
# Out:
# ['sir', 'intend', 'intervene', 'debate', 'physiotherapy', 'read', 'newspaper', 'think', 'bring', 'house', 'back', 'earth', 'mr', 'rajaratnam', 'great', 'virtue', 'midst', 'despondency', 'series', 'race', 'riot', 'thrown', 'independence', 'malay', 'singapore', 'apprehensive', 'majority', 'would', 'turn', 'treat', 'way', 'malay', 'majority', 'treat', 'us', 'draft', 'word', 'rise', 'present', 'great', 'idealist', 'come', 'trim', 'unachievable', 'pledge', 'stand', 'work', 'trim', 'ideology', 'aspiration', 'achieve', 'know', 'keep', 'try', 'nation', 'transition', 'want', 'move', 'amendment', 'amendment', 'acknowledge', 'progress', 'singapore', 'make', '50', 'year', 'since', 'attain', 'self', 'government', '1959', 'nation', 'build', 'achieve', 'aspiration', 'tenet', 'aspiration', 'ideology', 'sir', 'reference', 'make', 'constitution', 'constitution', 'singapore', 'enjoin', 'us', 'specially', 'look', 'position', 'malay', 'minority', 'come', 'article', '152', '153', 'explicitly', 'state', 'constitution', 'duty', 'behalf', 'government', 'treat', 'everybody', 'equal', 'reality', 'practical', 'lead', 'grave', 'irreparable', 'damage', 'work', 'principle', 'aspiration', 'malay', 'progress', 'number', 'join', 'middle', 'class', 'university', 'degrees', 'professional', 'qualification', 'ask', 'mendaki', 'agree', 'special', 'right', 'free', 'education', 'university', 'take', 'entitle', 'put', 'fee', 'help', 'disadvantage', 'malay', 'try', 'reach', 'position', 'level', 'play', 'field', 'everybody', 'go', 'take', 'decade', 'century', 'may', 'never', 'get', 'let', 'read', 'american', 'constitution', 'declaration', 'independence', '4th', 'july', '1776', 'adopt', 'congress', 'declaration', 'read', 'second', 'paragraph', 'hold', 'truth', 'self', 'evident', 'men', 'create', 'equal', 'endow', 'creator', 'certain', 'inalienable', 'right', 'among', 'life', 'liberty', 'pursuit', 'happiness', 'secure', 'right', 'government', 'institute', 'among', 'men', 'derive', 'power', 'consent', 'govern', 'nowhere', 'say', 'black', 'would', 'differently', 'treat', 'black', 'get', 'vote', 'civil', 'right', 'movement', '1960s', 'martin', 'luther', 'king', 'famous', 'speech', 'dare', 'dream', 'enormous', 'riot', 'take', 'place', 'eventually', 'president', 'johnson', 'pass', 'civil', 'right', 'act', 'take', 'many', 'decade', 'southern', 'state', 'keep', 'black', 'position', 'allow', 'registration', 'black', 'voter', 'subsequently', 'even', 'allow', 'black', 'student', 'go', 'white', 'school', '200', 'year', 'exceptional', 'half', 'black', 'american', 'become', 'president', 'colleague', 'put', 'try', 'put', 'square', 'peg', 'round', 'hole', 'ever', 'make', 'pegs', 'suggest', 'malay', 'abolish', 'provision', 'constitution', 'grave', 'disquiet', 'start', 'basis', 'reality', 'able', 'get', 'chinese', 'minister', 'indian', 'minister', 'persuade', 'malay', 'parent', 'look', 'daughter', 'carefully', 'teenage', 'pregnancy', 'lead', 'fail', 'marriage', 'subsequent', 'marriage', 'also', 'fail', 'delinquent', 'chinese', 'mp', 'indian', 'mp', 'say', 'interfere', 'private', 'life', 'fund', 'mendaki', 'muis', 'committee', 'try', 'reduce', 'number', 'unhappy', 'outcomes', 'way', 'singapore', 'make', 'progress', 'realistic', 'step', 'step', 'forward', 'approach', 'may', 'take', 'us', 'century', 'get', 'similar', 'position', 'american', 'go', 'war', 'black', 'white', 'first', 'world', 'war', 'carry', 'arm', 'carry', 'ammo', 'give', 'honour', 'fight', 'second', 'world', 'war', 'go', 'back', 'ex', 'gi', 'could', 'make', 'university', 'give', 'gi', 'grant', 'go', 'back', 'black', 'ghetto', '1945', 'stay', 'today', 'still', 'black', 'ghetto', 'reality', 'american', 'constitution', 'say', 'treat', 'black', 'differently', 'constitution', 'spell', 'duty', 'government', 'treat', 'malay', 'minority', 'extra', 'care', 'basis', 'nominate', 'member', 'place', 'argument', 'false', 'flaw', 'completely', 'untrue', 'get', 'basis', 'whatsoever', 'think', 'perhaps', 'bring', 'house', 'back', 'earth', 'rem ...

# %%
def word_cloud(lemma_words, color = 'black'):
    words = ' '.join(lemma_words)
    wordcloud = WordCloud(background_color=color,width=2500,height=2000).generate(words)
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    
word_cloud(data_freq,'white')

# %%
fdist = nltk.FreqDist(lemma_words)
freq_list=(fdist.most_common())
print(freq_list)

freq_dict={}

for i in freq_list:
    freq_dict[i[0]]=i[1]
# Out:
# [('malay', 8), ('constitution', 7), ('treat', 5), ('make', 5), ('right', 5), ('take', 5), ('go', 5), ('get', 5), ('black', 5), ('back', 4), ('singapore', 4), ('aspiration', 4), ('try', 4), ('government', 4), ('position', 4), ('read', 3), ('everybody', 3), ('reality', 3), ('university', 3), ('put', 3), ('say', 3), ('basis', 3), ('fail', 3), ('war', 3), ('think', 2), ('house', 2), ('riot', 2), ('independence', 2), ('majority', 2), ('way', 2), ('come', 2), ('trim', 2), ('work', 2), ('achieve', 2), ('keep', 2), ('nation', 2), ('amendment', 2), ('progress', 2), ('year', 2), ('look', 2), ('minority', 2), ('state', 2), ('lead', 2), ('grave', 2), ('number', 2), ('decade', 2), ('century', 2), ('declaration', 2), ('men', 2), ('life', 2), ('differently', 2), ('place', 2), ('president', 2), ('allow', 2), ('minister', 2), ('marriage', 2), ('step', 2), ('world', 2), ('carry', 2), ('give', 2), ('gi', 2), ('ghetto', 2), ('start', 2), ('sir', 1), ('intend', 1), ('debate', 1), ('physiotherapy', 1), ('newspaper', 1), ('bring', 1), ('mr', 1), ('rajaratnam', 1), ('virtue', 1), ('midst', 1), ('despondency', 1), ('series', 1), ('race', 1), ('turn', 1), ('draft', 1), ('word', 1), ('rise', 1), ('idealist', 1), ('pledge', 1), ('stand', 1), ('know', 1), ('transition', 1), ('want', 1), ('move', 1), ('acknowledge', 1), ('attain', 1), ('build', 1), ('tenet', 1), ('ideology', 1), ('reference', 1), ('enjoin', 1), ('specially', 1), ('article', 1), ('explicitly', 1), ('duty', 1), ('damage', 1), ('principle', 1), ('join', 1), ('class', 1), ('degrees', 1), ('qualification', 1), ('ask', 1), ('education', 1), ('entitle', 1), ('fee', 1), ('help', 1), ('disadvantage', 1), ('reach', 1), ('level', 1), ('play', 1), ('field', 1), ('never', 1), ('july', 1), ('adopt', 1), ('congress', 1), ('paragraph', 1), ('hold', 1), ('truth', 1), ('create', 1), ('endow', 1), ('creator', 1), ('liberty', 1), ('pursuit', 1), ('happiness', 1), ('secure', 1), ('institute', 1), ('derive', 1), ('power', 1), ('consent', 1), ('govern', 1), ('nowhere', 1), ('vote', 1), ('movement', 1), ('martin', 1), ('luther', 1), ('king', 1), ('speech', 1), ('dare', 1), ('dream', 1), ('eventually', 1), ('johnson', 1), ('pass', 1), ('act', 1), ('registration', 1), ('voter', 1), ('subsequently', 1), ('even', 1), ('student', 1), ('school', 1), ('half', 1), ('become', 1), ('colleague', 1), ('square', 1), ('peg', 1), ('round', 1), ('hole', 1), ('ever', 1), ('provision', 1), ('persuade', 1), ('parent', 1), ('daughter', 1), ('carefully', 1), ('teenage', 1), ('pregnancy', 1), ('also', 1), ('delinquent', 1), ('mp', 1), ('interfere', 1), ('fund', 1), ('muis', 1), ('committee', 1), ('reduce', 1), ('outcomes', 1), ('forward', 1), ('approach', 1), ('american', 1), ('white', 1), ('arm', 1), ('fight', 1), ('grant', 1), ('stay', 1), ('today', 1), ('still', 1), ('spell', 1), ('extra', 1), ('nominate', 1), ('member', 1), ('argument', 1), ('flaw', 1), ('completely', 1), ('whatsoever', 1), ('perhaps', 1), ('remind', 1), ('point', 1), ('base', 1), ('recognise', 1), ('foundation', 1)]

# %%
# Building the weighted histogram

# You calculate the number of occurences of each word
# In the end divide all values by max value so range is (0,1)

maxCount = max(freq_dict.values())
for key in freq_dict.keys():
    freq_dict[key] = freq_dict[key]/maxCount

# %%
# Sentence scores

# Add score for each word in a sentence to get sentence score

sent2score = {}
sentCount=0
for sentence in sent_list:
    for word in nltk.word_tokenize(sentence.lower()):
        if(len(sentence.split(' ')) < 25):  #Sent < 30 words
            #Check such that it's not biased towards long sentences over important sentences
            if word in freq_dict.keys():
                sentCount+=freq_dict[word]
            else:
                sentCount+=0
    sent2score[sentence] = sentCount

# %%
# Getting summary

best_sentences = heapq.nlargest(100, sent2score, key=sent2score.get)

# %% [raw]
# # Try later
#
# print("Sentences with Malay:")
# for sentence in best_sentences:
#     if "Malay" in sentence:
#         print("\t"+sentence)
#
# print("\nSentences with Black:")
# for sentence in best_sentences:
#     if "black" in sentence:
#         print("\t"+sentence)

# %%
# Clustering- on the lemmatized words

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(lemma_words)

true_k = 5
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)

print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print
# Out:
# Top terms per cluster:
# Cluster 0:
#  malay
#  black
#  treat
#  right
#  aspiration
#  try
#  government
#  singapore
#  position
#  reality
# Cluster 1:
#  constitution
#  year
#  fight
#  government
#  govern
#  gi
#  ghetto
#  fund
#  foundation
#  forward
# Cluster 2:
#  make
#  year
#  fee
#  govern
#  gi
#  ghetto
#  fund
#  foundation
#  forward
#  flaw
# Cluster 3:
#  declaration
#  year
#  field
#  government
#  govern
#  gi
#  ghetto
#  fund
#  foundation
#  forward
# Cluster 4:
#  stay
#  year
#  field
#  govern
#  gi
#  ghetto
#  fund
#  foundation
#  forward
#  flaw
