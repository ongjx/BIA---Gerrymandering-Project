# %%
# Importing Packages

import nltk #Tokenizing
import re #Preprocessing
import matplotlib.pyplot as plt
import bs4 as bs
import urllib.request #Scraping
import heapq #getting the top k largest sentences

# Importing classes within the packages

from nltk.corpus import PlaintextCorpusReader
from nltk.corpus import stopwords #Don't consider stopwords in histogram
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import *
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk import FreqDist
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# %%
from nltk.corpus import PlaintextCorpusReader
corpus = PlaintextCorpusReader('transcripts', '.+\.txt', encoding='Latin-1')
fids = corpus.fileids()
print(fids)
# Out:
# ['01_02_19.txt', '01_06_18.txt', '01_09_11.txt', '01_10_15.txt', '02_02_11.txt', '03_08_11.txt', '08_07_11.txt', '08_08_11.txt', '11_10_18.txt', '12_09_18.txt', '13_11_15.txt', '14_08_11.txt', '14_11_18.txt', '15_11_18.txt', '16_03_18.txt', '16_05_18.txt', '16_08_11.txt', '16_11_18.txt', '17_02_15.txt', '18_05_11.txt', '19_08_09.txt', '19_08_18.txt', '21_05_11.txt', '21_10_11.txt', '23_08_15.txt', '24_04_18.txt', '24_09_15.txt', '25_01_19.txt', '26_04_18.txt', '26_10_15.txt', '27_04_18.txt', '27_09_15.txt', '28_04_18.txt', '28_09_15.txt', '29_03_15.txt', '29_08_11.txt', '29_09_15.txt', '31_08_11.txt', '31_10_11.txt', '31_10_15.txt']

# %%
# convert words in each document to lower case
# For each file ID in fids, the code below takes its words. All these files are then combined into a single list called 'docs'.

doc_list = [corpus.words(f) for f in fids]
print(doc_list[1:3])
docs_lower = [[w.lower() for w in doc] for doc in doc_list]

# Use regular expression to keep only alphabetic words.

words_only = [[w for w in doc if re.search('^[a-z]+$', w)] for doc in docs_lower]
print(words_only[0][0:20])

# Remove stop words.
from nltk.corpus import stopwords
stop_list = stopwords.words('english')
docs_stopremoved = [[w for w in doc if w not in stop_list] for doc in words_only]


# Perform Porter stemming.
from nltk.stem.porter import *
stemmer = PorterStemmer()
docs_stem = [[stemmer.stem(w) for w in doc] for doc in docs_stopremoved]

# We use a Word Lemmatizer
lemmatizer = WordNetLemmatizer()
docs_lemma = [[lemmatizer.lemmatize(w) for w in doc] for doc in docs_stopremoved]

print(docs_lemma[0][0:10])
# Out:
# [['Prime', 'Minister', 'of', 'the', 'Republic', 'of', ...], ['Mr', 'President', 'Chief', 'Justice', 'Excellencies', ...]]
# ['this', 'year', 'we', 'are', 'commemorating', 'the', 'singapore', 'bicentennial', 'years', 'ago', 'stamford', 'raffles', 'arrived', 'in', 'singapore', 'that', 'marked', 'a', 'crucial', 'turning']
# ['year', 'commemorating', 'singapore', 'bicentennial', 'year', 'ago', 'stamford', 'raffle', 'arrived', 'singapore']

# %%
# Getting frequencies

list_of_all_words= []

[[list_of_all_words.append(w) for w in doc] for doc in docs_lemma]

fdist = nltk.FreqDist(list_of_all_words)
freq_list=(fdist.most_common())
print(freq_list)

freq_dict={}

for i in freq_list:
    freq_dict[i[0]]=i[1]
# Out:
# [('singapore', 707), ('year', 521), ('minister', 447), ('one', 433), ('u', 416), ('also', 363), ('mr', 360), ('people', 343), ('government', 332), ('many', 319), ('singaporean', 311), ('new', 301), ('think', 276), ('country', 255), ('make', 242), ('work', 241), ('time', 240), ('good', 227), ('together', 208), ('would', 199), ('need', 199), ('lee', 190), ('world', 180), ('flat', 179), ('well', 176), ('first', 173), ('china', 173), ('take', 172), ('help', 172), ('like', 169), ('life', 158), ('want', 158), ('must', 153), ('worker', 151), ('go', 151), ('society', 150), ('get', 150), ('problem', 148), ('prime', 146), ('come', 145), ('even', 144), ('way', 141), ('every', 141), ('election', 141), ('better', 140), ('next', 138), ('thing', 137), ('different', 135), ('ministry', 134), ('economy', 134), ('future', 133), ('two', 133), ('pm', 133), ('asean', 132), ('family', 132), ('national', 130), ('education', 130), ('home', 128), ('state', 128), ('team', 128), ('know', 126), ('may', 125), ('last', 121), ('look', 118), ('support', 117), ('change', 116), ('economic', 115), ('day', 115), ('job', 115), ('see', 114), ('another', 113), ('community', 110), ('president', 110), ('school', 110), ('issue', 109), ('term', 109), ('made', 108), ('say', 107), ('policy', 106), ('generation', 104), ('old', 104), ('keep', 104), ('going', 103), ('child', 101), ('right', 101), ('social', 100), ('important', 100), ('system', 99), ('cannot', 97), ('development', 96), ('long', 96), ('student', 95), ('forward', 94), ('continue', 91), ('senior', 90), ('best', 90), ('still', 89), ('said', 89), ('become', 87), ('business', 86), ('question', 86), ('dr', 84), ('trade', 83), ('group', 82), ('could', 82), ('young', 82), ('give', 82), ('whether', 82), ('able', 82), ('working', 81), ('opportunity', 81), ('much', 81), ('special', 80), ('chinese', 79), ('programme', 79), ('public', 79), ('back', 78), ('leader', 78), ('hdb', 78), ('hope', 77), ('company', 77), ('let', 77), ('part', 76), ('interest', 76), ('always', 75), ('mean', 74), ('today', 73), ('challenge', 73), ('strong', 72), ('done', 72), ('example', 72), ('got', 72), ('view', 71), ('hard', 71), ('environment', 71), ('put', 71), ('nation', 70), ('something', 70), ('mp', 70), ('foreign', 70), ('second', 69), ('especially', 69), ('major', 69), ('three', 69), ('city', 68), ('political', 68), ('build', 68), ('housing', 68), ('thank', 68), ('union', 68), ('place', 67), ('building', 66), ('income', 66), ('ago', 65), ('including', 65), ('feel', 65), ('technology', 64), ('area', 63), ('growth', 62), ('party', 62), ('office', 62), ('built', 61), ('global', 61), ('parent', 61), ('asia', 60), ('university', 60), ('population', 60), ('small', 60), ('big', 60), ('course', 59), ('start', 58), ('per', 58), ('care', 58), ('market', 57), ('benefit', 57), ('sure', 57), ('cabinet', 57), ('experience', 56), ('cooperation', 56), ('therefore', 56), ('around', 56), ('find', 56), ('lot', 56), ('friend', 55), ('grow', 55), ('high', 54), ('role', 54), ('project', 54), ('scheme', 54), ('responsibility', 54), ('worked', 54), ('quite', 54), ('agreement', 53), ('open', 52), ('beyond', 52), ('effort', 52), ('general', 52), ('secretary', 52), ('region', 51), ('service', 51), ('end', 51), ('industry', 51), ('close', 50), ('progress', 50), ('relationship', 50), ('level', 50), ('took', 50), ('g', 50), ('security', 49), ('already', 49), ('use', 49), ('making', 49), ('idea', 49), ('low', 49), ('set', 49), ('healthcare', 49), ('politics', 48), ('relation', 47), ('ask', 47), ('live', 47), ('number', 47), ('malaysia', 47), ('free', 46), ('member', 46), ('international', 46), ('water', 46), ('cost', 46), ('stay', 45), ('later', 45), ('step', 45), ('improve', 45), ('sense', 45), ('house', 45), ('cent', 45), ('little', 45), ('american', 45), ('point', 44), ('happy', 44), ('skill', 44), ('bring', 44), ('le', 44), ('getting', 44), ('taking', 43), ('key', 43), ('result', 43), ('understand', 43), ('speak', 42), ('happen', 42), ('chee', 42), ('value', 42), ('g ...

# %%
def word_cloud(list_of_all_words, color = 'black'):
    words = ' '.join(list_of_all_words)
    wordcloud = WordCloud(background_color=color,width=2500,height=2000).generate(words)
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    
word_cloud(list_of_all_words,'white')

# %%
import gensim
from gensim import corpora
dictionary = corpora.Dictionary(docs_stem)
print(dictionary)

# %%
# getting number of unique tokens
dictionary = corpora.Dictionary(docs_stem)
print(dictionary)

# we create a dictionary with the unique words
token_to_id = dictionary.token2id

# converting document to vector
first_doc = docs_stem[0]
print(first_doc[0:10])
# Out:
# Dictionary(5697 unique tokens: ['add', 'adjust', 'age', 'ago', 'along']...)
# ['year', 'commemor', 'singapor', 'bicentenni', 'year', 'ago', 'stamford', 'raffl', 'arriv', 'singapor']

# %%
# Converting all documents to a list of sparse vectors.

# Converting all documents in sample data to a list of sparse vectors.
# word ids are the same for all the documents in the list of documents

vecs = [dictionary.doc2bow(doc) for doc in docs_stem]
