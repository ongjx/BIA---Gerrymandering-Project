# %%
import pandas as pd

# %%
df = pd.read_csv("2015 household data.csv")

# %%
df.head()
# Out:
#                                Town   Total   Total Males  Total Females   \
# 0                Ang Mo Kio- Total   174,770        84,220         90,550
# 1           Ang Mo Kio Town Centre     5,020         2,370          2,640
# 2                        Cheng San    29,770        14,400         15,370
# 3                       Chong Boon    27,900        13,590         14,310
# 4                      Kebun Bahru    23,910        11,450         12,460
#
#    Total Chinese Chinese Males  Chinese Females  Total Malays Malay Males   \
# 0        143,290         68,860           74,430       13,060        6,430
# 1          4,260          2,020            2,240          210           90
# 2         24,660         11,890           12,770        2,140        1,080
# 3         22,910         11,150           11,760        1,950          950
# 4         19,210          9,160           10,060        2,200        1,090
#
# ...

# %%
df.columns = df.columns.str.strip()
#Remove extra spaces from column names so I can retrieve each column without any issues
#Part of data cleaning

# %%
df_copy = df.copy()

# %%
df_copy.Town = df_copy.Town.str.strip()

# %%
df_copy = df_copy[~df_copy.Town.str.contains("Total")]

# %%
df_copy.shape
# Out:
# (323, 16)

# %%
df.shape
# Out:
# (378, 16)

# %%
df_copy.head()
# Out:
#                      Town   Total Total Males Total Females Total Chinese  \
# 1  Ang Mo Kio Town Centre   5,020       2,370         2,640         4,260
# 2               Cheng San  29,770      14,400        15,370        24,660
# 3              Chong Boon  27,900      13,590        14,310        22,910
# 4             Kebun Bahru  23,910      11,450        12,460        19,210
# 5         Sembawang Hills   6,890       3,240         3,650         6,080
#
#   Chinese Males Chinese Females Total Malays Malay Males Malay Females  \
# 1         2,020           2,240          210          90           120
# 2        11,890          12,770        2,140       1,080         1,060
# 3        11,150          11,760        1,950         950         1,010
# 4         9,160          10,060        2,200       1,090         1,110
# 5         2,850           3,230          100          50            50
#
#   Total Indians Indian Males Indian Females Total Others Other Males  \
# ...
