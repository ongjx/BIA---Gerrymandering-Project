# %% [markdown]
# # 2010 Data

# %% [markdown]
# ## Loading data

# %%
import pandas as pd

df_2010 = pd.read_csv('2010 household data new 1.csv')

# %%
df_2010.head(15)
# Out:
#                                     Town   Total   Total Males   \
# 0                            Ang Mo Kio   179,297        87,113
# 1                             Cheng San    30,503        14,883
# 2                            Chong Boon    29,903        14,671
# 3                           Kebun Bahru    25,854        12,513
# 4                       Sembawang Hills     6,851         3,261
# 5                            Shangri-La    21,071        10,345
# 6                                 Sindo     7,287         3,520
# 7                Ang Mo Kio Town Centre     4,982         2,419
# 8                            Townsville    21,403        10,270
# 9                          Yio Chu Kang    31,443        15,231
# 10                                Bedok   294,519       144,400
# 11                             Bayshore     6,497         3,118
# 12                          Bedok North    91,139        44,879
# 13                      Bedok Reservoir    23,076        11,462
# 14                          Bedok South    52,313        25,584
#
#    Total Females   Total Chinese Chinese Males  Chinese Females  Total Malays  \
# 0          92,184        146,966         71,220           75,746       12,873
# 1          15,620         24,815         12,064           12,751        2,437
# 2          15,232         24,613         12,043           12,570        2,005
# 3          13,341         20,486          9,864           10,622        2,338
# 4           3,590          6,008          2,830            3,178          115
# 5          10,726         16,511          8,083            8,428        2,049
# 6           3,767          6,431          3,109            3,322           73
# 7           2,563          4,302          2,100            2,202          235
# 8          11,133         17,788          8,543            9,245        1,452
# 9          16,212         26,012         12,584           13,428        2,169
# 10        150,119        209,892        102,310          107,582       47,179
# 11          3,379          4,661          2,173            2,488          117
# 12         46,260         62,739         30,784           31,955       18,472
# 13         11,614         16,590          8,235            8,355        4,152
# 14         26,729         39,911         19,349           20,562        6,206
#
#    Malay Males  Malay Females  Total Indians Indian Males  Indian Females   \
# 0         6,355          6,518        14,952         7,532           7,420
# 1         1,221          1,216         2,539         1,291           1,248
# 2           989          1,016         2,625         1,346           1,279
# 3         1,172          1,166         2,331         1,167           1,164
# 4            58             57           526           263             263
# 5         1,023          1,026         2,034         1,035             999
# 6            32             41           518           259             259
# 7           108            127           296           142             154
# 8           691            761         1,683           823             860
# 9         1,061          1,108         2,400         1,206           1,194
# 10       23,178         24,001        25,348        13,028          12,320
# 11           46             71         1,017           523             494
# 12        9,192          9,280         6,993         3,554           3,439
# 13        2,053          2,099         1,629           855             774
# 14        3,043          3,163         3,660         1,913           1,747
#
#    Total Others  Other Males  Other Females
# 0          4,506        2,006          2,500
# 1            712          307            405
# 2            660          293            367
# 3            699          310            389
# 4            202          110             92
# 5            477          204            273
# 6            265          120            145
# 7            149           69             80
# 8            480          213            267
# 9            862          380            482
# 10        12,100        5,884          6,216
# 11           702          376            326
# 12         2,935        1,349          1,586
# 13           705          319            386
# 14         2,536        1,279          1,257

# %% [markdown]
# ## Cleaning dataset for 2010

# %%
def clean(text):
    cleaned = text[9:-1]
    return cleaned 
df_2010['Town'] = df_2010['Town'].apply(clean)

# %%
def checkfirst(text):
    if text[0].isalpha():
        return True
    return False
town_list = []
sub_town = []
curr_town = ""
     
for i in df_2010['Town']:
    if i[0].isalpha():
        curr_town = i.strip()
        town_list.append(curr_town)
        sub_town.append(curr_town)
    else:
        town_list.append(curr_town)
        sub_town.append(i.strip())

# %%
df_2010['main_town'] = pd.DataFrame(town_list)
df_2010['sub_town'] = pd.DataFrame(sub_town)

# %%
cols = ['main_town',
       'sub_town','Town', ' Total ', ' Total Males ', 'Total Females ', ' Total Chinese',
       'Chinese Males ', 'Chinese Females ', 'Total Malays', 'Malay Males ',
       'Malay Females ', 'Total Indians', 'Indian Males ', 'Indian Females ',
       'Total Others ', 'Other Males ', 'Other Females ']
df_2010 = df_2010[cols]
df_2010.columns = ['main_town',
       'sub_town','Town', 'Total', 'Total Males', 'Total Females', 'Total Chinese',
       'Chinese Males', 'Chinese Females', 'Total Malays', 'Malay Males',
       'Malay Females', 'Total Indians', 'Indian Males', 'Indian Females',
       'Total Others', 'Other Males', 'Other Females']

# %%
df_2010 = df_2010.drop(columns='Town')

# %%
df_2010.head(15)
# Out:
#      main_town                sub_town    Total Total Males Total Females  \
# 0   Ang Mo Kio              Ang Mo Kio  179,297      87,113        92,184
# 1   Ang Mo Kio               Cheng San   30,503      14,883        15,620
# 2   Ang Mo Kio              Chong Boon   29,903      14,671        15,232
# 3   Ang Mo Kio             Kebun Bahru   25,854      12,513        13,341
# 4   Ang Mo Kio         Sembawang Hills    6,851       3,261         3,590
# 5   Ang Mo Kio              Shangri-La   21,071      10,345        10,726
# 6   Ang Mo Kio                   Sindo    7,287       3,520         3,767
# 7   Ang Mo Kio  Ang Mo Kio Town Centre    4,982       2,419         2,563
# 8   Ang Mo Kio              Townsville   21,403      10,270        11,133
# 9   Ang Mo Kio            Yio Chu Kang   31,443      15,231        16,212
# 10       Bedok                   Bedok  294,519     144,400       150,119
# 11       Bedok                Bayshore    6,497       3,118         3,379
# 12       Bedok             Bedok North   91,139      44,879        46,260
# 13       Bedok         Bedok Reservoir   23,076      11,462        11,614
# 14       Bedok             Bedok South   52,313      25,584        26,729
#
#    Total Chinese Chinese Males Chinese Females Total Malays Malay Males  \
# 0        146,966        71,220          75,746       12,873       6,355
# 1         24,815        12,064          12,751        2,437       1,221
# 2         24,613        12,043          12,570        2,005         989
# 3         20,486         9,864          10,622        2,338       1,172
# 4          6,008         2,830           3,178          115          58
# 5         16,511         8,083           8,428        2,049       1,023
# 6          6,431         3,109           3,322           73          32
# 7          4,302         2,100           2,202          235         108
# 8         17,788         8,543           9,245        1,452         691
# 9         26,012        12,584          13,428        2,169       1,061
# 10       209,892       102,310         107,582       47,179      23,178
# 11         4,661         2,173           2,488          117          46
# 12        62,739        30,784          31,955       18,472       9,192
# 13        16,590         8,235           8,355        4,152       2,053
# 14        39,911        19,349          20,562        6,206       3,043
#
#    Malay Females Total Indians Indian Males Indian Females Total Others  \
# 0          6,518        14,952        7,532          7,420        4,506
# 1          1,216         2,539        1,291          1,248          712
# 2          1,016         2,625        1,346          1,279          660
# 3          1,166         2,331        1,167          1,164          699
# 4             57           526          263            263          202
# 5          1,026         2,034        1,035            999          477
# 6             41           518          259            259          265
# 7            127           296          142            154          149
# 8            761         1,683          823            860          480
# 9          1,108         2,400        1,206          1,194          862
# 10        24,001        25,348       13,028         12,320       12,100
# 11            71         1,017          523            494          702
# 12         9,280         6,993        3,554          3,439        2,935
# 13         2,099         1,629          855            774          705
# 14         3,163         3,660        1,913          1,747        2,536
#
#    Other Males Other Females
# 0        2,006         2,500
# 1          307           405
# 2          293           367
# 3          310           389
# 4          110            92
# 5          204           273
# 6          120           145
# 7           69            80
# 8          213           267
# 9          380           482
# 10       5,884         6,216
# 11         376           326
# 12       1,349         1,586
# 13         319           386
# 14       1,279         1,257

# %%
import re
def clean_comma(text):
    cleaned = re.sub(',', '',text)
    return int(cleaned)
data_2010 = df_2010.replace(' - ','0')
data_2010 = data_2010.replace(" NaN ", '0')
data_2010.drop('Total', axis=1,inplace= True)

cols = ['Total Males', 'Total Females', 'Total Chinese',
       'Chinese Males', 'Chinese Females', 'Total Malays', 'Malay Males',
       'Malay Females', 'Total Indians', 'Indian Males', 'Indian Females',
       'Total Others', 'Other Males', 'Other Females']
for i in cols:  
    data_2010[i] = data_2010[i].apply(clean_comma)

# %%
data_2010 = data_2010.drop(data_2010[data_2010.main_town == data_2010.sub_town].index)

# %%
data_2010
# Out:
#        main_town                sub_town  Total Males  Total Females  \
# 1     Ang Mo Kio               Cheng San        14883          15620
# 2     Ang Mo Kio              Chong Boon        14671          15232
# 3     Ang Mo Kio             Kebun Bahru        12513          13341
# 4     Ang Mo Kio         Sembawang Hills         3261           3590
# 5     Ang Mo Kio              Shangri-La        10345          10726
# 6     Ang Mo Kio                   Sindo         3520           3767
# 7     Ang Mo Kio  Ang Mo Kio Town Centre         2419           2563
# 8     Ang Mo Kio              Townsville        10270          11133
# 9     Ang Mo Kio            Yio Chu Kang        15231          16212
# 11         Bedok                Bayshore         3118           3379
# 12         Bedok             Bedok North        44879          46260
# 13         Bedok         Bedok Reservoir        11462          11614
# 14         Bedok             Bedok South        25584          26729
# 15         Bedok                 Frankel        14918          16618
# 16         Bedok              Kaki Bukit        21791          21990
# 17         Bedok               Kembangan        19216          19506
# 18         Bedok                  Siglap         3432           4023
# 20        Bishan             Bishan East        14693          15681
# 21        Bishan               Marymount        14438          14818
# 22        Bishan           Upper Thomson        15399          16269
# 24   Bukit Batok     Bukit Batok Central        13062          13491
# 25   Bukit Batok        Bukit Batok East         7994           7927
# 26   Bukit Batok       Bukit Batok South         7219           7432
# 27   Bukit Batok        Bukit Batok West         8050           8236
# 28   Bukit Batok                  Gombak         4336           4530
# 29   Bukit Batok                  Guilin         6807           7104
# 30   Bukit Batok                Hillview         8663           9279
# 31   Bukit Batok                Hong Kah        15230          14837
# 33   Bukit Merah          Alexandra Hill         8109           8236
# 34   Bukit Merah           Bukit Ho Swee         8133           8350
# ..           ...                     ...          ...            ...
# 192     Tampines                   Xilin         1064           1056
# 194      Tanglin              Chatsworth         2364           2663
# 195      Tanglin                  Nassim         3430           4101
# 196      Tanglin                  Ridout          604            662
# 197      Tanglin                Tyersall         1636           1833
# 199    Toa Payoh               Boon Teck         7934           8424
# 200    Toa Payoh                Braddell         5488           6048
# 201    Toa Payoh                 Kallang         4231           4438
# 202    Toa Payoh                Kim Keat         4427           4558
# 203    Toa Payoh               Marymount         6083           7129
# 204    Toa Payoh              Paya Lebar         3430           3422
# 205    Toa Payoh                Pei Chun         5970           6347
# 206    Toa Payoh            Potong Pasir         6655           6664
# 207    Toa Payoh                 Sennett         2119           2307
# 208    Toa Payoh       Toa Payoh Central        12690          14478
# 209    Toa Payoh               Woodleigh          892            909
# 5             1026           2034          1035             999           477
# 6               41            518           259             259           265
# 7              127            296           142             154           149
# 8              761           1683           823             860           480
# 9             1108           2400          1206            1194           862
# 11              71           1017           523             494           702
# 12            9280           6993          3554            3439          2935
# 13            2099           1629           855             774           705
# 14            3163           3660          1913            1747          2536
# 15             666           2677          1341            1336          2089
# 16            5367           4236          2232            2004          1197
# 17            3257           3748          1944            1804          1425
# 18              98           1388           666             722           511
# 20             858           2709          1374            1335           842
# 21             735           2275          1162            1113           777
# 22             521           2239          1124            1115          1108
# 24            1607           2494          1284            1210           631
# 25            1640           2395          1287            1108           390
# 26             917           1713           870             843           411
# 27            1285           2071          1100             971           350
# 28             385            607           291             316           191
# 29            1038           1418           723             695           499
# 30             191           1097           537             560           913
# 31            3240           3462          1850            1612           808
# 33             936           1755           908             847           359
# 34             736           1401           735             666           365
# ..             ...            ...           ...             ...           ...
# 192             22            100            58              42           188
# 194             26            633           309             324           792
# 195             46            537           262             275          1059
# 196              4            110            49              61           221
# 197             29            300           148             152           537
# 199           1073           1347           703             644           387
# 200            698            809           423             386           322
# 201            398            547           282             265           169
# 202            267            846           422             424           232
# 203            306            875           443             432           585
# 204            129            594           306             288           149
# 205            511            794           415             379           366
# 206            369           1593           823             770           249
# 207             27            244           127             117           115
# 208           1155           1846           896             950           811
# 209              3            112            55              57            87
# 211           4968           3517          1838            1679           793
# 212           2127           1942           994             948           255
# 213           4387           3693          1907            1786           973
# 214          10981          11059          5864            5195          2894
# 215           4183           3459          1801            1658           857
# 216           4074           3487          1821            1666           674
# 218            767           1177           564             613           332
# 219             19             62            29              33            29
# 220           3340           3552          1839            1713          1140
# 221             20            179            97              82            97
# 222             72            142            79              63            41
# 223           3093           3503          1804            1699           995
# 224           2798           4459          2260            2199          1116
# 225           5408           6610          3385            3225          1633
#
#      Other Males  Other Females
# 1            307            405
# 2            293            367
# 3            310            389
# 4            110             92
# 5            204            273
# 6            120            145
# 7             69             80
# 8            213            267
# 9            380            482
# 11           376            326
# 12          1349           1586
# 13           319            386
# 14          1279           1257
# 15          1044           1045
# 16           575            622
# 17           688            737
# 18           254            257
# 20           388            454
# 21           369            408
# 22           563            545
# 24           306            325
# 25           183            207
# 26           206            205
# 27           158            192
# 28            88            103
# 29           246            253
# 30           448            465
# 31           375            433
# 33           159            200
# 34           158            207
# ..           ...            ...
# 192           89             99
# 194          408            384
# 195          522            537
# 196          111            110
# 197          260            277
# 199          160            227
# 200          147            175
# 201           70             99
# 202           92            140
# 203          266            319
# 204           72             77
# 205          156            210
# 206          113            136
# 207           45             70
# 208          352            459
# 209           43             44
# 211          370            423
# 212          111            144
# 213          444            529
# 214         1422           1472
# 215          415            442
# 216          295            379
# 218          147            185
# 219           17             12
# 220          533            607
# 221           45             52
# 222           21             20
# 223          468            527
# 224          503            613
# 225          793            840
#
# [188 rows x 16 columns]

# %% [markdown]
# ## Grouping subtowns into their main towns

# %%
df_grpby_2010 = data_2010.groupby(['main_town','sub_town']).sum()
df_grpby_2010
# Out:
#                                     Total Males  Total Females  Total Chinese  \
# main_town   sub_town
# Ang Mo Kio  Ang Mo Kio Town Cent
#             Bukit Batok East                  1108           390          183
#             Bukit Batok South                  843           411          206
#             Bukit Batok West                   971           350          158
#             Gombak                             316           191           88
#             Guilin                             695           499          246
#             Hillview                           560           913          448
#             Hong Kah                          1612           808          375
# Bukit Merah Alexandra Hill                     847           359          159
#             Bukit Ho Swee                      666           365          158
# ...                                            ...           ...          ...
# Tampines    Xilin                               42           188           89
# Tanglin     Chatsworth                         324           792          408
#             Nassim                             275          1059          522
#             Ridout                              61           221          111
#             Tyersall                           152           537          260
# Toa Payoh   Boon Teck                          644           387          160
#             Braddell                           386           322          147
#             Kallang                            265           169           70
#             Kim Keat                           424           232           92
#             Marymount                          432           585          266
#             Paya Lebar                         288           149           72
#             Pei Chun                           379           366          156
#             Potong Pasir                       770           249          113
#             Sennett                            117           115           45
#             Toa Payoh Central                  950           811          352
#             Woodleigh                           57            87           43
# Woodlands   Midview                           1679           793          370
#             North Coast                        948           255          111
#             Woodgrove                         1786           973          444
#             Woodlands East                    5195          2894         1422
#             Woodlands South                   1658           857          415
#             Woodlands West                    1666           674          295
# Yishun      Khatib                             613           332          147
#             Lower Seletar                       33            29           17
#             Northland                         1713          1140          533
#             Springleaf                          82            97           45
#             Yishun Central                      63            41           21
#             Yishun East                       1699           995          468
#             Yishun South                      2199          1116          503
#             Yishun West                       3225          1633          793
#
#                                     Other Females
# main_town   sub_town
# Ang Mo Kio  Ang Mo Kio Town Centre             80
#             Cheng San                         405
#             Chong Boon                        367
#             Kebun Bahru                       389
#             Sembawang Hills                    92
#             Shangri-La                        273
#             Sindo                             145
#             Townsville                        267
#             Yio Chu Kang                      482
# Bedok       Bayshore                          326
#             Bedok North                      1586
#             Bedok Reservoir                   386
#             Bedok South                      1257
#             Frankel                          1045
#             Kaki Bukit                        622
#             Kembangan                         737
#             Siglap                            257
# Bishan      Bishan East                       454
#             Marymount                         408
#             Upper Thomson                     545
# Bukit Batok Bukit Batok Central               325
#             Bukit Batok East                  207
#             Bukit Batok South                 205
#             Bukit Batok West                  192
#             Gombak                            103
#             Guilin                            253
#             Hillview                          465
#             Hong Kah                          433
# Bukit Merah Alexandra Hill                    200
#             Bukit Ho Swee                     207
# ...                                           ...
# Tampines    Xilin                              99
# Tanglin     Chatsworth                        384
#             Nassim                            537
#             Ridout                            110
#             Tyersall                          277
# Toa Payoh   Boon Teck                         227
#             Braddell                          175
#             Kallang                            99
#             Kim Keat                          140
#             Marymount                         319
#             Paya Lebar                         77
#             Pei Chun                          210
#             Potong Pasir                      136
#             Sennett                            70
#             Toa Payoh Central                 459
#             Woodleigh                          44
# Woodlands   Midview                           423
#             North Coast                       144
#             Woodgrove                         529
#             Woodlands East                   1472
#             Woodlands South                   442
#             Woodlands West                    379
# Yishun      Khatib                            185
#             Lower Seletar                      12
#             Northland                         607
#             Springleaf                         52
#             Yishun Central                     20
#             Yishun East                       527
#             Yishun South                      613
#             Yishun West                       840
#
# [188 rows x 14 columns]

# %%
grpby_dict = df_grpby_2010.to_dict()

# %%
df_grpby_2010_copy = df_grpby_2010.copy()
list(df_grpby_2010_copy.reset_index()['main_town'].unique())
# df_grpby_2010_copy['main_town'].index
# Out:
# ['Ang Mo Kio',
#  'Bedok',
#  'Bishan',
#  'Bukit Batok',
#  'Bukit Merah',
#  'Bukit Panjang',
#  'Bukit Timah',
#  'Changi',
#  'Choa Chu Kang',
#  'Clementi',
#  'Downtown Core',
#  'Geylang',
#  'Hougang',
#  'Jurong East',
#  'Jurong West',
#  'Kallang',
#  'Marine Parade',
#  'Newton',
#  'Novena',
#  'Outram',
#  'Pasir Ris',
#  'Punggol',
#  'Queenstown',
#  'River Valley',
#  'Rochor',
#  'Sembawang',
#  'Sengkang',
#  'Serangoon',
#  'Singapore River',
#  'Tampines',
#  'Tanglin',
#  'Toa Payoh',
#  'Woodlands',
#  'Yishun']

# %% [markdown]
# # 2015 Data

# %% [markdown]
# ## Loading data

# %%
import pandas as pd

df_2015 = pd.read_csv('2015 household data new.csv')
df_2015.head()
# Out:
#                                Town   Total   Total Males  Total Females   \
# 0                        Ang Mo Kio  174,770        84,220         90,550
# 1           Ang Mo Kio Town Centre     5,020         2,370          2,640
# 2                        Cheng San    29,770        14,400         15,370
# 3                       Chong Boon    27,900        13,590         14,310
# 4                      Kebun Bahru    23,910        11,450         12,460
#
#    Total Chinese Chinese Males  Chinese Females  Total Malays Malay Males   \
# 0        143,290         68,860           74,430       13,060        6,430
# 1          4,260          2,020            2,240          210           90
# 2         24,660         11,890           12,770        2,140        1,080
# 3         22,910         11,150           11,760        1,950          950
# 4         19,210          9,160           10,060        2,200        1,090
#
#   Malay Females  Total Indians Indian Males  Indian Females  Total Others   \
# 0          6,640        14,150         7,050           7,100         4,270
# 1            120           360           170             190           190
# 2          1,060         2,380         1,210           1,170           600
# 3          1,010         2,400         1,230           1,170           630
# 4          1,110         1,910           940             960           590
#
#   Other Males  Other Females
# 0        1,890          2,390
# 1          100             90
# 2          230            370
# 3          260            370
# 4          270            330

# %% [markdown]
# ## Cleaning data

# %%
def clean(text):
    cleaned = text[5:]
    return cleaned 
df_2015['Town'] = df_2015['Town'].apply(clean)

# %%
town_list = []
sub_town = []
curr_town = ''
for i in df_2015['Town']:
    if i[0].isalpha():
        curr_town = i.strip()
        town_list.append(curr_town)
        sub_town.append(curr_town)
    else:
        town_list.append(curr_town)
        sub_town.append(i.strip())

# %%
# for i in range(len(town_list)):
#     if town_list[i] != None:
#         town_list[i] = town_list[i][0:-7]

# %%
df_2015['main_town'] = pd.DataFrame(town_list)
df_2015['sub_town'] = pd.DataFrame(sub_town)

# %%
cols = ['main_town',
       'sub_town','Town', ' Total ', ' Total Males ', 'Total Females ', ' Total Chinese',
       'Chinese Males ', 'Chinese Females ', 'Total Malays', 'Malay Males ',
       'Malay Females ', 'Total Indians', 'Indian Males ', 'Indian Females ',
       'Total Others ', 'Other Males ', 'Other Females ']
df_2015 = df_2015[cols]
df_2015.columns = ['main_town',
       'sub_town','Town', 'Total', 'Total Males', 'Total Females', 'Total Chinese',
       'Chinese Males', 'Chinese Females', 'Total Malays', 'Malay Males',
       'Malay Females', 'Total Indians', 'Indian Males', 'Indian Females',
       'Total Others', 'Other Males', 'Other Females']

# %%
df_2015 = df_2015.drop(columns='Town')

# %%
df_2015.head(15)
# Out:
#      main_town                sub_town    Total Total Males Total Females  \
# 0   Ang Mo Kio              Ang Mo Kio  174,770      84,220        90,550
# 1   Ang Mo Kio  Ang Mo Kio Town Centre    5,020       2,370         2,640
# 2   Ang Mo Kio               Cheng San   29,770      14,400        15,370
# 3   Ang Mo Kio              Chong Boon   27,900      13,590        14,310
# 4   Ang Mo Kio             Kebun Bahru   23,910      11,450        12,460
# 5   Ang Mo Kio         Sembawang Hills    6,890       3,240         3,650
# 6   Ang Mo Kio              Shangri-La   18,510       9,090         9,410
# 7   Ang Mo Kio                  Tagore    8,350       3,990         4,360
# 8   Ang Mo Kio              Townsville   23,770      11,300        12,470
# 9   Ang Mo Kio            Yio Chu Kang       30          -             -
# 10  Ang Mo Kio       Yio Chu Kang East    4,080       2,020         2,060
# 11  Ang Mo Kio      Yio Chu Kang North       -           -             -
# 12  Ang Mo Kio       Yio Chu Kang West   26,550      12,750        13,800
# 13       Bedok                   Bedok  289,750     141,220       148,530
# 14       Bedok                Bayshore    7,480       3,580         3,900
#
#    Total Chinese Chinese Males Chinese Females Total Malays Malay Males  \
# 0        143,290        68,860          74,430       13,060       6,430
# 1          4,260         2,020           2,240          210          90
# 2         24,660        11,890          12,770        2,140       1,080
# 3         22,910        11,150          11,760        1,950         950
# 4         19,210         9,160          10,060        2,200       1,090
# 5          6,080         2,850           3,230          100          50
# 6         13,900         6,810           7,090        2,410       1,200
# 7          7,440         3,540           3,900           70          40
# 8         19,630         9,320          10,310        1,660         800
# 9             -             -               -            -           -
# 10         3,620         1,790           1,830           50          30
# 11            -             -               -            -           -
# 12        21,540        10,330          11,220        2,270       1,110
# 13       208,880       101,010         107,870       43,980      21,640
# 14         5,240         2,450           2,790          130          50
#
#    Malay Females Total Indians Indian Males Indian Females Total Others  \
# 0          6,640        14,150        7,050          7,100        4,270
# 1            120           360          170            190          190
# 2          1,060         2,380        1,210          1,170          600
# 3          1,010         2,400        1,230          1,170          630
# 4          1,110         1,910          940            960          590
# 5             50           500          230            270          220
# 6          1,210         1,790          920            880          410
# 7             40           560          270            290          270
# 8            860         1,900          930            970          580
# 9             -             -            -              -            -
# 10            30           300          140            160          120
# 11            -             -            -              -            -
# 12         1,160         2,060        1,000          1,060          670
# 13        22,340        25,110       12,880         12,230       11,780
# 14            80         1,360          670            680          750
#
#    Other Males Other Females
# 0        1,890         2,390
# 1          100            90
# 2          230           370
# 3          260           370
# 4          270           330
# 5          110           110
# 6          170           240
# 7          140           140
# 8          250           330
# 9           -             -
# 10          60            50
# 11          -             -
# 12         310           370
# 13       5,690         6,090
# 14         410           340

# %%
data_2015 = df_2015.replace(' - ','0')
data_2015 = data_2015.replace(" NaN ", '0')
data_2015.drop('Total', axis=1,inplace= True)

cols = ['Total Males', 'Total Females', 'Total Chinese',
       'Chinese Males', 'Chinese Females', 'Total Malays', 'Malay Males',
       'Malay Females', 'Total Indians', 'Indian Males', 'Indian Females',
       'Total Others', 'Other Males', 'Other Females
# 7               40            560           270             290           270
# 8              860           1900           930             970           580
# 9                0              0             0               0             0
# 10              30            300           140             160           120
# 11               0              0             0               0             0
# 12            1160           2060          1000            1060           670
# 14              80           1360           670             680           750
# 15            8520           6430          3310            3120          2600
# 16            1900           2020          1020            1000           770
# 17            2990           3780          1960            1820          2410
# 18             640           2670          1360            1310          2310
# 19            4910           3780          1980            1800          1120
# 20            3250           3650          1900            1750          1400
# 21              70           1420           680             730           430
# 23             770           2560          1280            1280           790
# 24             670           2300          1190            1110           880
# 25             540           2140          1060            1080          1060
# 27               0              0             0               0             0
# 28               0              0             0               0             0
# 29               0              0             0               0             0
# 30               0              0             0               0             0
# 32               0              0             0               0             0
# 33            1660           2410          1220            1190           590
# 34            1530           1810           970             840           320
# ..             ...            ...           ...             ...           ...
# 342           1210           1990           940            1040           990
# 343            320            900           470             430           600
# 344             10            120            60              60           100
# 346              0              0             0               0             0
# 347              0              0             0               0             0
# 348              0              0             0               0             0
# 349              0              0             0               0             0
# 350              0              0             0               0             0
# 351              0              0             0               0             0
# 353              0              0             0               0             0
# 354              0              0             0               0             0
# 355              0              0             0               0             0
# 359              0              0             0               0             0
# 360           4870           3920          2060            1860           790
# 361           2110           1950          1000             940           280
# 362              0              0             0               0             0
# 363           4090           3730          1970            1760           910
# 364          10800          10730          5590            5150          2660
# 365              0              0             0               0             0
# 366           4500           3910          2010            1900          1080
# 367           4590           3560          1840            1720           670
# 369            710           1050           510             550           310
# 370            180            230           120             110            80
# 371             10             50            30              20            30
# 372           3040           3190          1600            1580          1100
# 373             20            190           100              90           100
# 374             70            130            70              60            30
# 375           5290           5350          2760            2600          1340
# 376           2490           4010          2020            2000           990
# 377           5180           6040          3110            2920          1530
#
#      Other Males  Other Females
# 1            100             90
# 2            230            370
# 3            260            370
# 4            270            330
# 5            110            110
# 6            170            240
# 7            140            140
# 8            250            330
# 9              0              0
# 10            60             50
# 11             0              0
# 12           310            370
# 14           410            340
# 15          1150           1450
# 16           350            420
# 17          1200           1210
# 18          1200           1110
# 19           510            610
# 20           650            750
# 21           220            210
# 23           360            430
# 24           430            450
# 25           530            520
# 27             0              0
# 28             0              0
# 29             0              0
# 30             0              0
# 32             0              0
# 33           270            320
# 34           150            170
# ..           ...            ...
# 342          450            550
# 343          280            320
# 344           50             50
# 346            0              0
# 347            0              0
# 348            0              0
# 349            0              0
# 350            0              0
# 351            0              0
# 353            0              0
# 354            0              0
# 355            0              0
# 359            0              0
# 360          360            430
# 361          130            140
# 362            0              0
# 363          420            490
# 364         1260           1400
# 365            0              0
# 366          540            540
# 367          280            390
# 369          150            160
# 370           50             30
# 371           20             10
# 372          510            590
# 373           50             50
# 374           10             20
# 375          590            760
# 376          440            550
# 377          700            830
#
# [311 rows x 16 columns]

# %% [markdown]
# ### Grouping subtowns into their main towns

# %%
df_grpby_2015 = data_2015.groupby(['main_town','sub_town'], as_index=True).sum()

# %%
df_grpby_2015
# Out:
#                                            Total Males  Total Females  \
# main_town       sub_town
# Ang Mo Kio      Ang Mo Kio Town Cent
#                 Cheng San                          230            370
#                 Chong Boon                         260            370
#                 Kebun Bahru                        270            330
#                 Sembawang Hills                    110            110
#                 Shangri-La                         170            240
#                 Tagore                             140            140
#                 Townsville                         250            330
#                 Yio Chu Kang                         0              0
#                 Yio Chu Kang East                   60             50
#                 Yio Chu Kang North                   0              0
#                 Yio Chu Kang West                  310            370
# Bedok           Bayshore                           410            340
#                 Bedok North                       1150           1450
#                 Bedok Reservoir                    350            420
#                 Bedok South                       1200           1210
#                 Frankel                           1200           1110
#                 Kaki Bukit                         510            610
#                 Kembangan                          650            750
#                 Siglap                             220            210
# Bishan          Bishan East                        360            430
#                 Marymount                          430            450
#                 Upper Thomson                      530            520
# Boon Lay        Liu Fang                             0              0
#                 Samulun                              0              0
#                 Shipyard                             0              0
#                 Tukang                               0              0
# Bukit Batok     Brickworks                           0              0
#                 Bukit Batok Central                270            320
#                 Bukit Batok East                   150            170
# ...                                                ...            ...
# Toa Payoh       Toa Payoh Central                  450            550
#                 Toa Payoh West                     280            320
#                 Woodleigh                           50             50
# Tuas            Tengeh                               0              0
#                 Tuas Bay                             0              0
#                 Tuas North                           0              0
#                 Tuas Promenade                       0              0
#                 Tuas View                            0              0
#                 Tuas View Extension                  0              0
# Western Islands Jurong Island and Bukom              0              0
#                 Semakau                              0              0
#                 Sudong                               0              0
# Woodlands       Greenwood Park                       0              0
#                 Midview                            360            430
#                 North Coast                        130            140
#                 Senoko West                          0              0
#                 Woodgrove                          420            490
#                 Woodlands East                    1260           1400
#                 Woodlands Regional Centre            0              0
#                 Woodlands South                    540            540
#                 Woodlands West                     280            390
# Yishun          Khatib                             150            160
#                 Lower Seletar                       50             30
#                 Nee Soon                            20             10
#                 Northland                          510            590
#                 Springleaf                          50             50
#                 Yishun Central                      10             20
#                 Yishun East                        590            760
#                 Yishun South                       440            550
#                 Yishun West                        700            830
#
# [311 rows x 14 columns]

# %% [markdown]
# ## Retrieval of only common towns

# %%
common_towns = ['Ang Mo Kio', 'Bukit Batok', 'Bukit Merah', 'Bukit Panjang', 'Changi', 'Choa Chu Kang', 'Clementi', 'Downtown Core', 'Geylang', 'Hougang', 'Jurong East', 'Jurong West', 'Kallang', 'Mandai', 'Marine Parade', 'Newton', 'Novena', 'Outram', 'Pasir Ris', 'Punggol']
cols = ['Total', 'Total Males', 'Total Females', 'Total Chinese',
       'Chinese Males', 'Chinese Females', 'Total Malays', 'Malay Males',
       'Malay Females', 'Total Indians', 'Indian Males', 'Indian Females',
       'Total Others', 'Other Males', 'Other Females']

x = pd.DataFrame()
for i in range(len(df_grpby_2015)):
    if df_grpby_2015.index[i][0] in common_towns:
        x = x.append(df_grpby_2015.iloc[i])
for i in range(len(df_grpby_2010)):
    if df_grpby_2015.index[i][0] in common_towns:
        x = x.append(df_grpby_2010.iloc[i])

# %%
common_towns = ['Ang Mo Kio', 'Bukit Batok', 'Bukit Merah', 'Bukit Panjang', 'Changi', 'Choa Chu Kang', 'Clementi', 'Downtown Core', 'Geylang', 'Hougang', 'Jurong East', 'Jurong West', 'Kallang', 'Mandai', 'Marine Parade', 'Newton', 'Novena', 'Outram', 'Pasir Ris', 'Punggol']
cols = ['Total', 'Total Males', 'Total Females', 'Total Chinese',
       'Chinese Males', 'Chinese Females', 'Total Malays', 'Malay Males',
       'Malay Females', 'Total Indians', 'Indian Males', 'Indian Females',
       'Total Others', 'Other Males', 'Other Females']

data_2010 = pd.DataFrame()
data_2015 = pd.DataFrame()
for i in range(len(df_grpby_2010)):
    if df_grpby_2010.index[i][0] in common_towns:
        data_2010 = data_2010.append(df_grpby_2010.iloc[i])

for i in range(len(df_grpby_2015)):
    if df_grpby_2015.index[i][0] in common_towns:
        data_2015 = data_2015.append(df_grpby_2015.iloc[i])

# %%
x = x.reset_index()

# %% [markdown]
# #### *condition here refers to the list of common subtowns between 2010 and 2015*

# %%
constant_sub_towns = pd.DataFrame(x['index'].value_counts() == 2).reset_index()
constant_sub_towns = constant_sub_towns[constant_sub_towns['index'] == True]
condition = constant_sub_towns['level_0'].values.tolist()

x[x['index'].isin(condition)].head()
# Out:
#                                   index  Chinese Females  Chinese Males  \
# 0  (Ang Mo Kio, Ang Mo Kio Town Centre)           2240.0         2020.0
# 1               (Ang Mo Kio, Cheng San)          12770.0        11890.0
# 2              (Ang Mo Kio, Chong Boon)          11760.0        11150.0
# 3             (Ang Mo Kio, Kebun Bahru)          10060.0         9160.0
# 4         (Ang Mo Kio, Sembawang Hills)           3230.0         2850.0
#
#    Indian Females  Indian Males  Malay Females  Malay Males  Other Females  \
# 0           190.0         170.0          120.0         90.0           90.0
# 1          1170.0        1210.0         1060.0       1080.0          370.0
# 2          1170.0        1230.0         1010.0        950.0          370.0
# 3           960.0         940.0         1110.0       1090.0          330.0
# 4           270.0         230.0           50.0         50.0          110.0
#
#    Other Males  Total Chinese  Total Females  Total Indians  Total Malays  \
# 0        100.0         4260.0         2640.0          360.0         210.0
# 1        230.0        24660.0        15370.0         2380.0        2140.0
# 2        260.0        22910.0        14310.0         2400.0        1950.0
# 3        270.0        19210.0        12460.0         1910.0        2200.0
# 4        110.0         6080.0         3650.0          500.0         100.0
#
#    Total Males  Total Others
# 0       2370.0         190.0
# 1      14400.0         600.0
# 2      13590.0         630.0
# 3      11450.0         590.0
# 4       3240.0         220.0

# %%
data_2010 = data_2010.reset_index()
data_2015 = data_2015.reset_index()

# %%
data_2015_common = data_2015[data_2015['index'].isin(condition)].set_index("index")
data_2010_common = data_2010[data_2010['index'].isin(condition)].set_index("index")

# %% [markdown]
# ### Obtaining the % difference between 2015 and 2010

# %%
perc_difference = (data_2015_common - data_2010_common)/data_2010_common * 100
perc_difference.head()
# Out:
#                                       Chinese Females  Chinese Males  \
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)         1.725704      -3.809524
# (Ang Mo Kio, Cheng San)                      0.149008      -1.442308
# (Ang Mo Kio, Chong Boon)                    -6.443914      -7.415096
# (Ang Mo Kio, Kebun Bahru)                   -5.290906      -7.137064
# (Ang Mo Kio, Sembawang Hills)                1.636249       0.706714
#
#                                       Indian Females  Indian Males  \
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)       23.376623     19.718310
# (Ang Mo Kio, Cheng San)                    -6.250000     -6.274206
# (Ang Mo Kio, Chong Boon)                   -8.522283     -8.618128
# (Ang Mo Kio, Kebun Bahru)                 -17.525773    -19.451585
# (Ang Mo Kio, Sembawang Hills)               2.661597    -12.547529
#
#                                       Malay Females  Malay Males  \
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)      -5.511811   -16.666667
# (Ang Mo Kio, Cheng San)                  -12.828947   -11.547912
# (Ang Mo Kio, Chong Boon)                  -0.590551    -3.943377
# (Ang Mo Kio, Kebun Bahru)                 -4.802744    -6.996587
# (Ang Mo Kio, Sembawang Hills)            -12.280702   -13.793103
#
#                                       Other Females  Other Males  \
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)      12.500000    44.927536
# (Ang Mo Kio, Cheng San)                   -8.641975   -25.081433
# (Ang Mo Kio, Chong Boon)                   0.817439   -11.262799
# (Ang Mo Kio, Kebun Bahru)                -15.167095   -12.903226
# (Ang Mo Kio, Sembawang Hills)             19.565217     0.000000
#
#                                       Total Chinese  Total Females  \
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)      -0.976290       3.004292
# (Ang Mo Kio, Cheng San)                   -0.624622      -1.600512
# (Ang Mo Kio, Chong Boon)                  -6.919108      -6.053046
# (Ang Mo Kio, Kebun Bahru)                 -6.228644      -6.603703
# (Ang Mo Kio, Sembawang Hills)              1.198402       1.671309
#
#                                       Total Indians  Total Malays  \
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)      21.621622    -10.638298
# (Ang Mo Kio, Cheng San)                   -6.262308    -12.187115
# (Ang Mo Kio, Chong Boon)                  -8.571429     -2.743142
# (Ang Mo Kio, Kebun Bahru)                -18.060918     -5.902481
# (Ang Mo Kio, Sembawang Hills)             -4.942966    -13.043478
#
#                                       Total Males  Total Others
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)    -2.025630     27.516779
# (Ang Mo Kio, Cheng San)                 -3.245313    -15.730337
# (Ang Mo Kio, Chong Boon)                -7.368278     -4.545455
# (Ang Mo Kio, Kebun Bahru)               -8.495165    -15.593705
# (Ang Mo Kio, Sembawang Hills)           -0.643974      8.910891

# %% [markdown]
# ### Obtaining the absolute difference between 2015 and 2010

# %%
abs_difference = (data_2015_common - data_2010_common)

# %%
abs_difference.head()
# Out:
#                                       Chinese Females  Chinese Males  \
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)             38.0          -80.0
# (Ang Mo Kio, Cheng San)                          19.0         -174.0
# (Ang Mo Kio, Chong Boon)                       -810.0         -893.0
# (Ang Mo Kio, Kebun Bahru)                      -562.0         -704.0
# (Ang Mo Kio, Sembawang Hills)                    52.0           20.0
#
#                                       Indian Females  Indian Males  \
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)            36.0          28.0
# (Ang Mo Kio, Cheng San)                        -78.0         -81.0
# (Ang Mo Kio, Chong Boon)                      -109.0        -116.0
# (Ang Mo Kio, Kebun Bahru)                     -204.0        -227.0
# (Ang Mo Kio, Sembawang Hills)                    7.0         -33.0
#
#                                       Malay Females  Malay Males  \
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)           -7.0        -18.0
# (Ang Mo Kio, Cheng San)                      -156.0       -141.0
# (Ang Mo Kio, Chong Boon)                       -6.0        -39.0
# (Ang Mo Kio, Kebun Bahru)                     -56.0        -82.0
# (Ang Mo Kio, Sembawang Hills)                  -7.0         -8.0
#
#                                       Other Females  Other Males  \
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)           10.0         31.0
# (Ang Mo Kio, Cheng San)                       -35.0        -77.0
# (Ang Mo Kio, Chong Boon)                        3.0        -33.0
# (Ang Mo Kio, Kebun Bahru)                     -59.0        -40.0
# (Ang Mo Kio, Sembawang Hills)                  18.0          0.0
#
#                                       Total Chinese  Total Females  \
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)          -42.0           77.0
# (Ang Mo Kio, Cheng San)                      -155.0         -250.0
# (Ang Mo Kio, Chong Boon)                    -1703.0         -922.0
# (Ang Mo Kio, Kebun Bahru)                   -1276.0         -881.0
# (Ang Mo Kio, Sembawang Hills)                  72.0           60.0
#
#                                       Total Indians  Total Malays  \
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)           64.0         -25.0
# (Ang Mo Kio, Cheng San)                      -159.0        -297.0
# (Ang Mo Kio, Chong Boon)                     -225.0         -55.0
# (Ang Mo Kio, Kebun Bahru)                    -421.0        -138.0
# (Ang Mo Kio, Sembawang Hills)                 -26.0         -15.0
#
#                                       Total Males  Total Others
# index
# (Ang Mo Kio, Ang Mo Kio Town Centre)        -49.0          41.0
# (Ang Mo Kio, Cheng San)                    -483.0        -112.0
# (Ang Mo Kio, Chong Boon)                  -1081.0         -30.0
# (Ang Mo Kio, Kebun Bahru)                 -1063.0        -109.0
# (Ang Mo Kio, Sembawang Hills)               -21.0          18.0

# %%
difference_df = df_grpby_2015-df_grpby_2010

# %%
difference_clean = difference_df.dropna()

# %%
difference_clean.columns
difference_clean.drop(['Total Males',"Total Females","Total Chinese", "Total Malays","Total Indians","Total Others"], axis = 1,inplace=True)
# Out:
# C:\Users\Zexel Lew\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
difference_df_perc = (df_grpby_2015-df_grpby_2010)/df_grpby_2010*100
# difference_df_perc.head()
difference_df_perc.dropna(inplace=True)
difference_df_perc.drop(['Total Males',"Total Females","Total Chinese", "Total Malays","Total Indians","Total Others"], axis = 1,inplace=True)
difference_df_perc.head()
# Out:
#                                    Chinese Males  Chinese Females  \
# main_town  sub_town
# Ang Mo Kio Ang Mo Kio Town Centre      -3.809524         1.725704
#            Cheng San                   -1.442308         0.149008
#            Chong Boon                  -7.415096        -6.443914
#            Kebun Bahru                 -7.137064        -5.290906
#            Sembawang Hills              0.706714         1.636249
#
#                                    Malay Males  Malay Females  Indian Males  \
# main_town  sub_town
# Ang Mo Kio Ang Mo Kio Town Centre   -16.666667      -5.511811     19.718310
#            Cheng San                -11.547912     -12.828947     -6.274206
#            Chong Boon                -3.943377      -0.590551     -8.618128
#            Kebun Bahru               -6.996587      -4.802744    -19.451585
#            Sembawang Hills          -13.793103     -12.280702    -12.547529
#
#                                    Indian Females  Other Males  Other Females
# main_town  sub_town
# Ang Mo Kio Ang Mo Kio Town Centre       23.376623    44.927536      12.500000
#            Cheng San                    -6.250000   -25.081433      -8.641975
#            Chong Boon                   -8.522283   -11.262799       0.817439
#            Kebun Bahru                 -17.525773   -12.903226     -15.167095
#            Sembawang Hills               2.661597     0.000000      19.565217

# %%
def summation(col1, col2):
    if col1 < 0 and col2 < 0:
        return col1 - col2
    else:
        return col1 + col2 

chineseChange_df = pd.DataFrame(difference_clean[['Chinese Males', "Chinese Females"]].apply(lambda x: summation(x['Chinese Males'],x['Chinese Females']),axis =1),columns=["net_change_chinese"])
display(chineseChange_df.head())
chineseMainTownChange_df = chineseChange_df.reset_index().groupby('main_town').sum()
display(chineseMainTownChange_df.head())

chinesePercChange_df = pd.DataFrame(difference_df_perc[['Chinese Males', "Chinese Females"]].apply(lambda x: summation(x['Chinese Males'],x['Chinese Females']),axis =1),columns=["perc_change_chinese"])
display(chinesePercChange_df.head())
chineseMainTownPercChange_df = chinesePercChange_df.reset_index().groupby('main_town').sum()
display(chineseMainTownPercChange_df.head())
# Out:
#                                    net_change_chinese
# main_town  sub_town
# Ang Mo Kio Ang Mo Kio Town Centre               -42.0
#            Cheng San                           -155.0
#            Chong Boon                           -83.0
#            Kebun Bahru                         -142.0
#            Sembawang Hills                       72.0
#              net_change_chinese
# main_town
# Ang Mo Kio               2401.0
# Bedok                    3888.0
# Bishan                   2001.0
# Bukit Batok              1129.0
# Bukit Merah              4270.0
#                                    perc_change_chinese
# main_town  sub_town
# Ang Mo Kio Ang Mo Kio Town Centre            -2.083820
#            Cheng San                         -1.293300
#            Chong Boon                        -0.971182
#            Kebun Bahru                       -1.846158
#            Sembawang Hills                    2.342963
#              perc_change_chinese
# main_town
# Ang Mo Kio             16.889959
# Bedok                  63.478527
# Bishan                 15.615389
# Bukit Batok            28.093006
# Bukit Merah           202.125004

# %% [markdown]
# ### Malay Info

# %%
malayChange_df = pd.DataFrame(difference_clean[['Malay Males', "Malay Females"]].apply(lambda x: summation(x['Malay Males'],x['Malay Females']),axis =1),columns=["net_change_malay"])
display(malayChange_df.head())
malayMainTownChange_df = malayChange_df.reset_index().groupby('main_town').sum()
display(malayMainTownChange_df.head())

malayPercChange_df = pd.DataFrame(difference_df_perc[['Malay Males', "Malay Females"]].apply(lambda x: summation(x['Malay Males'],x['Malay Females']),axis =1),columns=["perc_change_malay"])
display(malayPercChange_df.head())
malayMainTownPercChange_df = malayPercChange_df.reset_index().groupby('main_town').sum()
display(malayMainTownPercChange_df.head())
# Out:
#                                    net_change_malay
# main_town  sub_town
# Ang Mo Kio Ang Mo Kio Town Centre             -11.0
#            Cheng San                           15.0
#            Chong Boon                         -33.0
#            Kebun Bahru                        -26.0
#            Sembawang Hills                     -1.0
#              net_change_malay
# main_town
# Ang Mo Kio              560.0
# Bedok                   121.0
# Bishan                   31.0
# Bukit Batok              99.0
# Bukit Merah            2144.0
#                                    perc_change_malay
# main_town  sub_town
# Ang Mo Kio Ang Mo Kio Town Centre         -11.154856
#            Cheng San                        1.281036
#            Chong Boon                      -3.352826
#            Kebun Bahru                     -2.193843
#            Sembawang Hills                 -1.512402
#              perc_change_malay
# main_town
# Ang Mo Kio           47.086325
# Bedok                17.299066
# Bishan                4.601568
# Bukit Batok           6.525481
# Bukit Merah         844.322752

# %% [markdown]
# ### Indian Info

# %%
indianChange_df = pd.DataFrame(difference_clean[['Indian Males', "Indian Females"]].apply(lambda x: summation(x['Indian Males'],x['Indian Females']),axis =1),columns=["net_change_indian"])
display(indianChange_df.head())
indianMainTownChange_df = indianChange_df.reset_index().groupby('main_town').sum()
display(indianMainTownChange_df.head())

indianPercChange_df = pd.DataFrame(difference_df_perc[['Indian Males', "Indian Females"]].apply(lambda x: summation(x['Indian Males'],x['Indian Females']),axis =1),columns=["perc_change_indian"])
display(indianPercChange_df.head())
indianMainTownPercChange_df = indianPercChange_df.reset_index().groupby('main_town').sum()
display(indianMainTownPercChange_df.head())
# Out:
#                                    net_change_indian
# main_town  sub_town
# Ang Mo Kio Ang Mo Kio Town Centre               64.0
#            Cheng San                            -3.0
#            Chong Boon                           -7.0
#            Kebun Bahru                         -23.0
#            Sembawang Hills                     -26.0
#              net_change_indian
# main_town
# Ang Mo Kio               214.0
# Bedok                    896.0
# Bishan                   -43.0
# Bukit Batok              -71.0
# Bukit Merah              305.0
#                                    perc_change_indian
# main_town  sub_town
# Ang Mo Kio Ang Mo Kio Town Centre           43.094933
#            Cheng San                        -0.024206
#            Chong Boon                       -0.095845
#            Kebun Bahru                      -1.925812
#            Sembawang Hills                  -9.885932
#              perc_change_indian
# main_town
# Ang Mo Kio            57.755852
# Bedok                125.602195
# Bishan                -3.136329
# Bukit Batok           13.030983
# Bukit Merah          208.375339

# %% [markdown]
# ### Other Info

# %%
otherChange_df = pd.DataFrame(difference_clean[['Other Males', "Other Females"]].apply(lambda x: summation(x['Other Males'],x['Other Females']),axis =1),columns=["net_change_other"])
display(otherChange_df.head())
otherMainTownChange_df = otherChange_df.reset_index().groupby('main_town').sum()
display(otherMainTownChange_df.head())

otherPercChange_df = pd.DataFrame(difference_df_perc[['Other Males', "Other Females"]].apply(lambda x: summation(x['Other Males'],x['Other Females']),axis =1),columns=["perc_change_other"])
display(otherPercChange_df.head())
otherMainTownPercChange_df = otherPercChange_df.reset_index().groupby('main_town').sum()
display(otherMainTownPercChange_df.head())
# Out:
#                                    net_change_other
# main_town  sub_town
# Ang Mo Kio Ang Mo Kio Town Centre              41.0
#            Cheng San                          -42.0
#            Chong Boon                         -30.0
#            Kebun Bahru                         19.0
#            Sembawang Hills                     18.0
#              net_change_other
# main_town
# Ang Mo Kio              207.0
# Bedok                   174.0
# Bishan                   91.0
# Bukit Batok              79.0
# Bukit Merah             427.0
#                                    perc_change_other
# main_town  sub_town
# Ang Mo Kio Ang Mo Kio Town Centre          57.427536
#            Cheng San                      -16.439458
#            Chong Boon                     -10.445360
#            Kebun Bahru                      2.263869
#            Sembawang Hills                 19.565217
#              perc_change_other
# main_town
# Ang Mo Kio           88.759448
# Bedok                36.179214
# Bishan               23.620831
# Bukit Batok          35.310456
# Bukit Merah         565.233602

# %% [markdown]
# ## All races combined into one DataFrame

# %%
allChange_df = chineseChange_df.join([malayChange_df,indianChange_df,otherChange_df])
allPercChange_df = chinesePercChange_df.join([malayPercChange_df,indianPercChange_df,otherPercChange_df])
display(allChange_df.reset_index().groupby('main_town').sum())
display(allPercChange_df.reset_index().groupby('main_town').sum())
# Out:
#                  net_change_chinese  net_change_malay  net_change_indian  \
# main_town
# Ang Mo Kio                   2401.0             560.0              214.0
# Bedok                        3888.0             121.0              896.0
# Bishan                       2001.0              31.0              -43.0
# Bukit Batok                  1129.0              99.0              -71.0
# Bukit Merah                  4270.0            2144.0              305.0
# Bukit Panjang                9251.0            2255.0             1433.0
# Bukit Timah                  3796.0              90.0              237.0
# Changi                        127.0             167.0               42.0
# Choa Chu Kang                 226.0             869.0              321.0
# Clementi                     5336.0             426.0              196.0
# Downtown Core                 -32.0               0.0                0.0
# Geylang                      1130.0             348.0             -144.0
# Hougang                      1007.0              81.0             -180.0
# Jurong East                  1242.0               0.0               45.0
# Jurong West                  3412.0             306.0              443.0
# Kallang                      3282.0             955.0              764.0
# Marine Parade                 626.0              17.0              307.0
# Newton                        466.0              -3.0               80.0
# Novena                       1409.0             114.0               58.0
# Outram                       2048.0             656.0              193.0
# Pasir Ris                    1445.0             427.0               53.0
# Queenstown                   2284.0             898.0              128.0
# River Valley                  673.0              41.0              157.0
# Rochor                        107.0             122.0              -75.0
# Clementi                 25.510410
# Downtown Core            53.968254
# Geylang                  -8.907962
# Hougang                   1.630039
# Jurong East              34.591032
# Jurong West              23.240304
# Kallang                 149.820134
# Marine Parade            41.035722
# Newton                   60.491991
# Novena                   23.778245
# Outram                   89.906621
# Pasir Ris               154.423842
# Queenstown               78.454214
# River Valley            132.238314
# Rochor                  -37.911913
# Sembawang                43.004224
# Sengkang                  4.534355
# Serangoon               -20.470085
# Singapore River          64.057827
# Tampines                  7.700511
# Tanglin                  39.186210
# Toa Payoh                90.502225
# Woodlands                58.867434
# Yishun                  343.510650

# %% [markdown]
# ## Transferred table from Election_statistics file
# #### This table is the subtraction result between 2015 and 2011

# %%
df_elec_stats = pd.DataFrame({'vote_count': {('Aljunied', 'GRC', 'WP'): -2239.0,
  ('Ang Mo Kio', 'GRC', 'RP'): 22639.0,
  ('Bishan-Toa Payoh', 'GRC', 'SPP'): 24316.0,
  ('Bukit Panjang', 'SMC', 'SDP'): 1579.0,
  ('Chua Chu Kang', 'GRC', 'PAP'): "nan",
  ('Chua Chu Kang', 'GRC', 'PPP'): "nan",
  ('East Coast', 'GRC', 'WP'): -4899.0,
  ('Holland-Bukit Timah', 'GRC', 'SDP'): 14013.0,
  ('Hong Kah North', 'SMC', 'SPP'): 1472.0,
  ('Hougang', 'SMC', 'WP'): -1823.0,
  ('Jurong', 'GRC', 'PAP'): "nan",
  ('Jurong', 'GRC', 'SGF'): "nan",
  ('Marine Parade', 'GRC', 'PAP'): "nan",
  ('Marine Parade', 'GRC', 'WP'): "nan",
  ('Mountbatten', 'SMC', 'PAP'): "nan",
  ('Mountbatten', 'SMC', 'SPP'): "nan",
  ('Nee Soon', 'GRC', 'WP'): 1547.0,
  ('Pasir Ris-Punggol', 'GRC', 'SDA'): 24673.0,
  ('Pioneer', 'SMC', 'PAP'): 3424.0,
  ('Potong Pasir', 'SMC', 'SPP'): 2610.0,
  ('Punggol East', 'SMC', 'WP'): -17.0,
  ('Radin Mas', 'SMC', 'PAP'): "nan",
  ('Radin Mas', 'SMC', 'RP'): "nan",
  ('Sembawang', 'GRC', 'PAP'): "nan",
  ('Sembawang', 'GRC', 'SDP'): "nan",
  ('Sengkang West', 'SMC', 'WP'): 2897.0,
  ('Tampines', 'GRC', 'PAP'): 22577.0,
  ('Tanjong Pagar', 'GRC', 'PAP'): "nan",
  ('Tanjong Pagar', 'GRC', 'SGF'): "nan",
  ('West Coast', 'GRC', 'RP'): -1349.0,
  ('Yuhua', 'SMC', 'SDP'): 1231.0},
 'vote_percentage': {('Aljunied', 'GRC', 'WP'): -0.03759999999999997,
  ('Ang Mo Kio', 'GRC', 'RP'): 0.09309999999999996,
  ('Bishan-Toa Payoh', 'GRC', 'SPP'): 0.16659999999999997,
  ('Bukit Panjang', 'SMC', 'SDP'): 0.021100000000000008,
  ('Chua Chu Kang', 'GRC', 'PAP'): "nan",
  ('Chua Chu Kang', 'GRC', 'PPP'): "nan",
  ('East Coast', 'GRC', 'WP'): 0.05899999999999994,
  ('Holland-Bukit Timah', 'GRC', 'SDP'): 0.06520000000000004,
  ('Hong Kah North', 'SMC', 'SPP'): 0.04150000000000009,
  ('Hougang', 'SMC', 'WP'): -0.07140000000000002,
  ('Jurong', 'GRC', 'PAP'): "nan",
  ('Jurong', 'GRC', 'SGF'): "nan",
  ('Marine Parade', 'GRC', 'PAP'): "nan",
  ('Marine Parade', 'GRC', 'WP'): "nan",
  ('Mountbatten', 'SMC', 'PAP'): "nan",
  ('Mountbatten', 'SMC', 'SPP'): "nan",
  ('Nee Soon', 'GRC', 'WP'): 0.08430000000000004,
  ('Pasir Ris-Punggol', 'GRC', 'SDA'): 0.08099999999999996,
  ('Pioneer', 'SMC', 'PAP'): 0.1562,
  ('Potong Pasir', 'SMC', 'SPP'): 0.1603,
  ('Punggol East', 'SMC', 'WP'): -0.027699999999999947,
  ('Radin Mas', 'SMC', 'PAP'): "nan",
  ('Radin Mas', 'SMC', 'RP'): "nan",
  ('Sembawang', 'GRC', 'PAP'): "nan",
  ('Sembawang', 'GRC', 'SDP'): "nan",
  ('Sengkang West', 'SMC', 'WP'): 0.040200000000000014,
  ('Tampines', 'GRC', 'PAP'): 0.14849999999999997,
  ('Tanjong Pagar', 'GRC', 'PAP'): "nan",
  ('Tanjong Pagar', 'GRC', 'SGF'): "nan",
  ('West Coast', 'GRC', 'RP'): 0.12,
  ('Yuhua', 'SMC', 'SDP'): 0.06690000000000007}})

# %%
df_elec_stats_1 = df_elec_stats[df_elec_stats['vote_count'] != 'nan']
df_elec_stats_2 = df_elec_stats_1.reset_index().set_index('level_0')

# %%
import statsmodels.api as sm

# %%
import pprint
data = {'Bishan': ['Bishan-Toa Payoh'], 'Bukit Merah': ['Jalan Besar', 'Radin Mas', 'Tanjong Pagar', 'West Coast'], 'Geylang': ['Jalan Besar', 'MacPherson', 'Marine Parade', 'Mountbatten', 'Potong Pasir'], 'Kallang': ['Jalan Besar', 'Mountbatten', 'Tanjong Pagar'], 'Marine Parade': ['Marine Parade', 'Mountbatten'], 'Queenstown': ['Holland-Bukit Timah', 'Tanjong Pagar', 'West Coast'], 'Toa Payoh': ['Bishan-Toa Payoh', 'Marine Parade', 'Potong Pasir'], 'Bedok': ['Aljunied', 'East Coast', 'Fengshan', 'Marine Parade'], 'Changi': ['East Coast'], 'Pasir Ris': ['Pasir Ris-Punggol'], 'North-Eastern Islands': ['East Coast'], 'Tampines': ['Aljunied', 'Pasir Ris-Punggol', 'East Coast', 'Tampines'], 'Central Water Catchment': ['Holland-Bukit Timah'], 'Woodlands': ['Marsiling-Yew Tee', 'Sembawang'], 'Ang Mo Kio': ['Ang Mo Kio', 'Nee Soon'], 'Bukit Batok': ['Bukit Batok', 'Chua Chu Kang', 'Hong Kah North', 'Jurong'], 'Bukit Panjang': ['Bukit Panjang', 'Holland-Bukit Timah'], 'Clementi': ['Holland-Bukit Timah', 'Jurong', 'West Coast'], 'Bukit Timah': ['Holland-Bukit Timah', 'Jurong', 'Tanjong Pagar'], 'Central Area': ['Jalan Besar', 'Mountbatten', 'Tanjong Pagar'], 'Jurong East': ['Jurong', 'West Coast', 'Yuhua'], 'Tuas': ['West Coast'], 'Western Water Catchment': ['Chua Chu Kang'], 'Sungei Kadut': ['Marsiling-Yew Tee'], 'Choa Chu Kang': ['Chua Chu Kang', 'Marsiling-Yew Tee'], 'Tengah': ['Hong Kah North'], 'Novena': ['Bishan-Toa Payoh', 'Holland-Bukit Timah', 'Jalan Besar', 'Tanjong Pagar'], 'Serangoon': ['Aljunied', 'Ang Mo Kio', 'Marine Parade'], 'Hougang': ['Aljunied', 'Ang Mo Kio', 'Hougang', 'Marine Parade'], 'Mandai': ['Marsiling-Yew Tee', 'Nee Soon'], 'Yishun': ['Ang Mo Kio', 'Nee Soon', 'Sembawang'], 'Sembawang': ['Sembawang'], 'Seletar': ['Ang Mo Kio'], 'Punggol': ['Pasir Ris-Punggol']}

scraped_data = {}
for key in data:
    list_of_const = data[key]
    
    for item in list_of_const:
        if item not in scraped_data:
            scraped_data[item] = [key]
        else:
            scraped_data[item] += [key]
    
pprint.pprint(scraped_data)
# Out:
# {'Aljunied': ['Bedok', 'Tampines', 'Serangoon', 'Hougang'],
#  'Ang Mo Kio': ['Ang Mo Kio', 'Serangoon', 'Hougang', 'Yishun', 'Seletar'],
#  'Bishan-Toa Payoh': ['Bishan', 'Toa Payoh', 'Novena'],
#  'Bukit Batok': ['Bukit Batok'],
#  'Bukit Panjang': ['Bukit Panjang'],
#  'Chua Chu Kang': ['Bukit Batok', 'Western Water Catchment', 'Choa Chu Kang'],
#  'East Coast': ['Bedok', 'Changi', 'North-Eastern Islands', 'Tampines'],
#  'Fengshan': ['Bedok'],
#  'Holland-Bukit Timah': ['Queenstown',
#                          'Central Water Catchment',
#                          'Bukit Panjang',
#                          'Clementi',
#                          'Bukit Timah',
#                          'Novena'],
#  'Hong Kah North': ['Bukit Batok', 'Tengah'],
#  'Hougang': ['Hougang'],
#  'Jalan Besar': ['Bukit Merah', 'Geylang', 'Kallang', 'Central Area', 'Novena'],
#  'Jurong': ['Bukit Batok', 'Clementi', 'Bukit Timah', 'Jurong East'],
#  'MacPherson': ['Geylang'],
#  'Marine Parade': ['Geylang',
#                    'Marine Parade',
#                    'Toa Payoh',
#                    'Bedok',
#                    'Serangoon',
#                    'Hougang'],
#  'Marsiling-Yew Tee': ['Woodlands', 'Sungei Kadut', 'Choa Chu Kang', 'Mandai'],
#  'Mountbatten': ['Geylang', 'Kallang', 'Marine Parade', 'Central Area'],
#  'Nee Soon': ['Ang Mo Kio', 'Mandai', 'Yishun'],
#  'Pasir Ris-Punggol': ['Pasir Ris', 'Tampines', 'Punggol'],
#  'Potong Pasir': ['Geylang', 'Toa Payoh'],
#  'Radin Mas': ['Bukit Merah'],
#  'Sembawang': ['Woodlands', 'Yishun', 'Sembawang'],
#  'Tampines': ['Tampines'],
#  'Tanjong Pagar': ['Bukit Merah',
#                    'Kallang',
#                    'Queenstown',
#                    'Bukit Timah',
#                    'Central Area',
#                    'Novena'],
#  'West Coast': ['Bukit Merah', 'Queenstown', 'Clementi', 'Jurong East', 'Tuas'],
#  'Yuhua': ['Jurong East']}

# %%
allChangeSummed = allChange_df.reset_index().groupby('main_town').sum()

# %%
allChangeSummed.loc['Ang Mo Kio']['net_change_chinese']
# Out:
# 2401.0

# %%
total_votes_grc = {}
for k,v in scraped_data.items():
    for town in v:
        try:
            if k not in total_votes_grc:
                total_votes_grc[k] = [allChangeSummed.loc[town]['net_change_chinese']]
            else:
                total_votes_grc[k][0] += allChangeSummed.loc[town]['net_change_chinese']
        except:
            print(town)
total_votes_grc
# Out:
# Central Area
# Central Area
# Tuas
# Central Area
# Central Water Catchment
# North-Eastern Islands
# Punggol
# Sungei Kadut
# Mandai
# Seletar
# Mandai
# Western Water Catchment
# Tengah
# {'Bishan-Toa Payoh': [6898.0],
#  'Jalan Besar': [10091.0],
#  'Radin Mas': [4270.0],
#  'Tanjong Pagar': [15041.0],
#  'West Coast': [13132.0],
#  'MacPherson': [1130.0],
#  'Marine Parade': [11780.0],
#  'Mountbatten': [5038.0],
#  'Potong Pasir': [4618.0],
#  'Holland-Bukit Timah': [22076.0],
#  'Aljunied': [8515.0],
#  'East Coast': [5994.0],
#  'Fengshan': [3888.0],
#  'Pasir Ris-Punggol': [3424.0],
#  'Tampines': [1979.0],
#  'Marsiling-Yew Tee': [5247.0],
#  'Sembawang': [24961.0],
#  'Ang Mo Kio': [21641.0],
#  'Nee Soon': [18993.0],
#  'Bukit Batok': [1129.0],
#  'Chua Chu Kang': [1355.0],
#  'Hong Kah North': [1129.0],
#  'Jurong': [11503.0],
#  'Bukit Panjang': [9251.0],
#  'Yuhua': [1242.0],
#  'Hougang': [1007.0]}

# %%
chinese_demo = pd.DataFrame.from_dict(total_votes_grc).T
chinese_demo = chinese_demo.reset_index().set_index('index')
chinese_merged = df_elec_stats_2.join([chinese_demo])
chinese_merged.columns = ['constituency_type', 'party','vote_count','vote_percentage','change_in_chinese']
chinese_merged.index.name='constituency'
chinese_merged.sort_values(by='change_in_chinese')
# Out:
#                     constituency_type party vote_count vote_percentage  \
# constituency
# Hougang                           SMC    WP      -1823         -0.0714
# Hong Kah North                    SMC   SPP       1472          0.0415
# Yuhua                             SMC   SDP       1231          0.0669
# Tampines                          GRC   PAP      22577          0.1485
# Pasir Ris-Punggol                 GRC   SDA      24673           0.081
# Potong Pasir                      SMC   SPP       2610          0.1603
# East Coast                        GRC    WP      -4899           0.059
# Bishan-Toa Payoh                  GRC   SPP      24316          0.1666
# Aljunied                          GRC    WP      -2239         -0.0376
# Bukit Panjang                     SMC   SDP       1579          0.0211
# West Coast                        GRC    RP      -1349            0.12
# Nee Soon                          GRC    WP       1547          0.0843
# Ang Mo Kio                        GRC    RP      22639          0.0931
# Holland-Bukit Timah               GRC   SDP      14013          0.0652
# Pioneer                           SMC   PAP       3424          0.1562
# Punggol East                      SMC    WP        -17         -0.0277
# Sengkang West                     SMC    WP       2897          0.0402
#
#                      change_in_chinese
# constituency
# Hougang                         1007.0
# Hong Kah North                  1129.0
# Yuhua                           1242.0
# Tampines                        1979.0
# Pasir Ris-Punggol               3424.0
# Potong Pasir                    4618.0
# East Coast                      5994.0
# Bishan-Toa Payoh                6898.0
# Aljunied                        8515.0
# Bukit Panjang                   9251.0
# West Coast                     13132.0
# Nee Soon                       18993.0
# Ang Mo Kio                     21641.0
# Holland-Bukit Timah            22076.0
# Pioneer                            NaN
# Punggol East                       NaN
# Sengkang West                      NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
def getRaceDict(race):
    total_votes_grc = {}
    for k,v in scraped_data.items():
        for town in v:
            try:
                if k not in total_votes_grc:
                    total_votes_grc[k] = [allChangeSummed.loc[town]['net_change_'+race.lower()]]
                else:
                    total_votes_grc[k][0] += allChangeSummed.loc[town]['net_change_'+race.lower()]
            except:
                pass
    return total_votes_grc

def createRaceDataFrame(race):
    total_votes_grc = getRaceDict(race)
    race_demo = pd.DataFrame.from_dict(total_votes_grc).T
    race_demo = race_demo.reset_index().set_index('index')
    race_merged = df_elec_stats_2.join([race_demo])
    race_merged.columns = ['constituency_type', 'party','vote_count','vote_percentage','change_in_'+race.lower()]
    race_merged.index.name='constituency'
    return race_merged

def plotRaceDataFrame(race):
    merged = createRaceDataFrame(race)
    merged = merged.fillna(0)
    sns.regplot(y=merged['vote_count'],x=merged['change_in_'+race.lower()])
    return merged
    
def raceSummary(race):
    merged = plotRaceDataFrame(race)
    results = sm.OLS(merged['change_in_'+race.lower()],merged['vote_count']).fit()
    # plt.plot(chinese_merged['change_in_chinese'],results.fittedvalues, c='red')
    print(results.summary())

# %%
raceSummary('chinese')
createRaceDataFrame('chinese')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      change_in_chinese   R-squared:                       0.268
# Model:                            OLS   Adj. R-squared:                  0.223
# Method:                 Least Squares   F-statistic:                     5.867
# Date:                Thu, 24 Jan 2019   Prob (F-statistic):             0.0277
# Time:                        22:09:00   Log-Likelihood:                -178.39
# No. Observations:                  17   AIC:                             358.8
# Df Residuals:                      16   BIC:                             359.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# vote_count     0.4370      0.180      2.422      0.028       0.055       0.820
# ==============================================================================
# Omnibus:                        1.218   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.544   Jarque-Bera (JB):                0.877
# Skew:                           0.236   Prob(JB):                        0.645
# Kurtosis:                       1.992   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\Zexel Lew\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Zexel Lew\Anaconda3\lib\site-packages\scipy\stats\stats.py:1394: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   "anyway, n=%i" % int(n))
#                     constituency_type party vote_count vote_percentage  \
# constituency
# Aljunied                          GRC    WP      -2239         -0.0376
# Ang Mo Kio                        GRC    RP      22639          0.0931
# Bishan-Toa Payoh                  GRC   SPP      24316          0.1666
# Bukit Panjang                     SMC   SDP       1579          0.0211
# East Coast                        GRC    WP      -4899           0.059
# Holland-Bukit Timah               GRC   SDP      14013          0.0652
# Hong Kah North                    SMC   SPP       1472          0.0415
# Hougang                           SMC    WP      -1823         -0.0714
# Nee Soon                          GRC    WP       1547          0.0843
# Pasir Ris-Punggol                 GRC   SDA      24673           0.081
# Pioneer                           SMC   PAP       3424          0.1562
# Potong Pasir                      SMC   SPP       2610          0.1603
# Punggol East                      SMC    WP        -17         -0.0277
# Sengkang West                     SMC    WP       2897          0.0402
# Tampines                          GRC   PAP      22577          0.1485
# West Coast                        GRC    RP      -1349            0.12
# Yuhua                             SMC   SDP       1231          0.0669
#
#                      change_in_chinese
# constituency
# Aljunied                        8515.0
# Ang Mo Kio                     21641.0
# Bishan-Toa Payoh                6898.0
# Bukit Panjang                   9251.0
# East Coast                      5994.0
# Holland-Bukit Timah            22076.0
# Hong Kah North                  1129.0
# Hougang                         1007.0
# Nee Soon                       18993.0
# Pasir Ris-Punggol               3424.0
# Pioneer                            NaN
# Potong Pasir                    4618.0
# Punggol East                       NaN
# Sengkang West                      NaN
# Tampines                        1979.0
# West Coast                     13132.0
# Yuhua                           1242.0

# %%
raceSummary('malay')
createRaceDataFrame('malay')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        change_in_malay   R-squared:                       0.199
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     3.973
# Date:                Thu, 24 Jan 2019   Prob (F-statistic):             0.0636
# Time:                        22:09:01   Log-Likelihood:                -153.71
# No. Observations:                  17   AIC:                             309.4
# Df Residuals:                      16   BIC:                             310.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# vote_count     0.0842      0.042      1.993      0.064      -0.005       0.174
# ==============================================================================
# Omnibus:                        2.128   Durbin-Watson:                   2.420
# Prob(Omnibus):                  0.345   Jarque-Bera (JB):                1.521
# Skew:                           0.710   Prob(JB):                        0.467
# Kurtosis:                       2.636   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\Zexel Lew\Anaconda3\lib\site-packages\scipy\stats\stats.py:1394: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   "anyway, n=%i" % int(n))
#                     constituency_type party vote_count vote_percentage  \
# constituency
# Aljunied                          GRC    WP      -2239         -0.0376
# Ang Mo Kio                        GRC    RP      22639          0.0931
# Bishan-Toa Payoh                  GRC   SPP      24316          0.1666
# Bukit Panjang                     SMC   SDP       1579          0.0211
# East Coast                        GRC    WP      -4899           0.059
# Holland-Bukit Timah               GRC   SDP      14013          0.0652
# Hong Kah North                    SMC   SPP       1472          0.0415
# Hougang                           SMC    WP      -1823         -0.0714
# Nee Soon                          GRC    WP       1547          0.0843
# Pasir Ris-Punggol                 GRC   SDA      24673           0.081
# Pioneer                           SMC   PAP       3424          0.1562
# Potong Pasir                      SMC   SPP       2610          0.1603
# Punggol East                      SMC    WP        -17         -0.0277
# Sengkang West                     SMC    WP       2897          0.0402
# Tampines                          GRC   PAP      22577          0.1485
# West Coast                        GRC    RP      -1349            0.12
# Yuhua                             SMC   SDP       1231          0.0669
#
#                      change_in_malay
# constituency
# Aljunied                       411.0
# Ang Mo Kio                    5362.0
# Bishan-Toa Payoh               519.0
# Bukit Panjang                 2255.0
# East Coast                     418.0
# Holland-Bukit Timah           3783.0
# Hong Kah North                  99.0
# Hougang                         81.0
# Nee Soon                      5202.0
# Pasir Ris-Punggol              557.0
# Pioneer                          NaN
# Potong Pasir                   722.0
# Punggol East                     NaN
# Sengkang West                    NaN
# Tampines                       130.0
# West Coast                    3468.0
# Yuhua                            0.0

# %%
raceSummary('indian')
createRaceDataFrame('indian')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       change_in_indian   R-squared:                       0.192
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     3.792
# Date:                Thu, 24 Jan 2019   Prob (F-statistic):             0.0693
# Time:                        22:09:02   Log-Likelihood:                -140.38
# No. Observations:                  17   AIC:                             282.8
# Df Residuals:                      16   BIC:                             283.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# vote_count     0.0376      0.019      1.947      0.069      -0.003       0.078
# ==============================================================================
# Omnibus:                        2.746   Durbin-Watson:                   1.576
# Prob(Omnibus):                  0.253   Jarque-Bera (JB):                1.637
# Skew:                           0.512   Prob(JB):                        0.441
# Kurtosis:                       1.877   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\Zexel Lew\Anaconda3\lib\site-packages\scipy\stats\stats.py:1394: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   "anyway, n=%i" % int(n))
#                     constituency_type party vote_count vote_percentage  \
# constituency
# Aljunied                          GRC    WP      -2239         -0.0376
# Ang Mo Kio                        GRC    RP      22639          0.0931
# Bishan-Toa Payoh                  GRC   SPP      24316          0.1666
# Bukit Panjang                     SMC   SDP       1579          0.0211
# East Coast                        GRC    WP      -4899           0.059
# Holland-Bukit Timah               GRC   SDP      14013          0.0652
# Hong Kah North                    SMC   SPP       1472          0.0415
# Hougang                           SMC    WP      -1823         -0.0714
# Nee Soon                          GRC    WP       1547          0.0843
# Pasir Ris-Punggol                 GRC   SDA      24673           0.081
# Pioneer                           SMC   PAP       3424          0.1562
# Potong Pasir                      SMC   SPP       2610          0.1603
# Punggol East                      SMC    WP        -17         -0.0277
# Sengkang West                     SMC    WP       2897          0.0402
# Tampines                          GRC   PAP      22577          0.1485
# West Coast                        GRC    RP      -1349            0.12
# Yuhua                             SMC   SDP       1231          0.0669
#
#                      change_in_indian
# constituency
# Aljunied                       1068.0
# Ang Mo Kio                     1863.0
# Bishan-Toa Payoh                180.0
# Bukit Panjang                  1433.0
# East Coast                     1383.0
# Holland-Bukit Timah            2052.0
# Hong Kah North                  -71.0
# Hougang                        -180.0
# Nee Soon                       2136.0
# Pasir Ris-Punggol               498.0
# Pioneer                           NaN
# Potong Pasir                     21.0
# Punggol East                      NaN
# Sengkang West                     NaN
# Tampines                        445.0
# West Coast                      674.0
# Yuhua                            45.0

# %%
raceSummary('other')
# Out:
# C:\Users\Zexel Lew\Anaconda3\lib\site-packages\scipy\stats\stats.py:1394: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   "anyway, n=%i" % int(n))
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        change_in_other   R-squared:                       0.235
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     4.922
# Date:                Thu, 24 Jan 2019   Prob (F-statistic):             0.0413
# Time:                        22:09:02   Log-Likelihood:                -122.27
# No. Observations:                  17   AIC:                             246.5
# Df Residuals:                      16   BIC:                             247.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# vote_count     0.0147      0.007      2.219      0.041       0.001       0.029
# ==============================================================================
# Omnibus:                        0.285   Durbin-Watson:                   1.592
# Prob(Omnibus):                  0.867   Jarque-Bera (JB):                0.436
# Skew:                           0.220   Prob(JB):                        0.804
# Kurtosis:                       2.350   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.subplots(figsize=(20,10))
a1 = plt.subplot(221)
a1 = plotRaceDataFrame('chinese')
a2 = plt.subplot(222)
a2 = plotRaceDataFrame('malay')
a3 = plt.subplot(223)
a3 = plotRaceDataFrame('indian')
a4 = plt.subplot(224)
a4 = plotRaceDataFrame('other')

# %%
list_of_cols = list(perc_difference.columns)
perc_difference_total = {}
for col in list_of_cols:
    if 'Total' in col:
        perc_difference_total[col] = perc_difference[col]

perc_difference_total = pd.DataFrame.from_dict(perc_difference_total)
perc_difference_total.head()

def get_town(name_of_town):
    return name_of_town[1]


# perc_difference_total_frame['index'].apply(get_town)
